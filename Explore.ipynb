# %% [markdown]
# # Exploring health facility data

# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %%
df = pd.read_csv('health_facility_assessment_cleaned.csv',index_col=0)
df.dtypes
# Out:
# facility_name                                                                 object
# facility_gps_lat                                                             float64
# facility_gps_lon                                                             float64
# region_province                                                               object
# district                                                                      object
# chiefdom                                                                      object
# facility_location                                                             object
# facility_type_other                                                          float64
# managing_authority_other                                                      object
# outpatient_only                                                               object
# capacity.number_consultation_rooms                                           float64
# capacity.number_inpatient_beds                                               float64
# capacity.number_maternity_beds                                               float64
# cho_number_in_post                                                           float64
# cho_number_present_at_visit                                                  float64
# cht_number_in_post                                                           float64
# cht_number_present_at_visit                                                  float64
# cha_number_in_post                                                           float64
# cha_number_present_at_visit                                                  float64
# cm_number_in_post                                                            float64
# cm_number_present_at_visit                                                   float64
# sechn_number_in_post                                                         float64
# sechn_number_present_at_visit                                                float64
# lab_tech_number_in_post                                                      float64
# lab_tech_number_present_at_visit                                             float64
# mch_aides_number_in_post                                                     float64
# mch_aides_number_present_at_visit                                            float64
# cleaner_porter_number_in_post                                                float64
# cleaner_porter_number_present_at_visit                                       float64
# other_number_in_post                                                         float64
# other_number_present_at_visit                                                float64
# other_staff_cadre                                                             object
# sections_to_review                                                            object
# consultations.head_count.month_1                                             float64
# consultations.head_count.month_2                                             float64
# consultations.head_count.month_3                                             float64
# consultations.head_count.month_4                                             float64
# consultations.general_outpatient.month_1                                     float64
# consultations.general_outpatient.month_2                                     float64
# consultations.general_outpatient.month_3                                     float64
# consultations.general_outpatient.month_4                                     float64
# consultations.deliveries.month_1                                             float64
# consultations.deliveries.month_2                                             float64
# consultations.deliveries.month_3                                             float64
# consultations.deliveries.month_4                                             float64
# consultations.pent_vaccines.month_1                                          float64
# consultations.pent_vaccines.month_2                                          float64
# consultations.pent_vaccines.month_3                                          float64
# consultations.pent_vaccines.month_4                                          float64
# hr_focal_point                                                               float64
# hr_staff_received_info                                                       float64
# hr_healthcare_provider_training                                              float64
# hr_healthcare_provider_revised_training                                      float64
# hr_daily_staff_list                                                          float64
# iec_handwashing_procedure                                                     object
# iec_physical_distancing                                                       object
# iec_covering_nose_mouth                                                       object
# iec_early_symptom_recognition                                                 object
# iec_when_facility_vs_home                                                     object
# iec_rational_ppe_use                                                          object
# iec_helpline_number                                                           object
# surv_procedure_for_notification                                              float64
# surv_official_case_definition                                                float64
# surv_hotline_number                                                          float64
# surv_timely_data_reported_to_district                                        float64
# ter_screening_area_set_up                                                    float64
# ter_symptom_screening_questionnaires                                         float64
# ter_temperature_measurement_at_triage                                        float64
# ter_physical_distancing_in_waiting                                           float64
# ter_separate_waiting_for_symptomatic                                         float64
# chw_trained_precautions                                                      float64
# chw_trained_community_service                                                float64
# chw_drugs                                                                    float64
# chw_gloves                                                                   float64
# chw_masks                                                                    float64
# chw_iec_materials                                                            float64
# iso_designated_isolation_for_suspected                                       float64
# iso_distance_between_patients_in_waiting                                     float64
# iso_distance_between_patient_beds                                            float64
# iso_transfer_referral_protocol                                               float64
# ipc_ppe_medical_masks                                                        float64
# ipc_ppe_disp_surgical_masks                                                  float64
# ipc_ppe_eye_protection                                                       float64
# ipc_ppe_examination_gloves                                                   float64
# ipc_ppe_surgical_gloves                                                      float64
# ipc_ppe_long_cuffed_gloves                                                   float64
# ipc_ppe_heavy_duty_gloves                                                    float64
# ipc_ppe_long_sleeved_gown                                                    float64
# ipc_ppe_waterproof_aprons                                                    float64
# ipc_ppe_plan_staff_trained_on_ppe                                            float64
# ipc_ppe_plan_ppe_poster_displayed                                            float64
# ipc_ppe_plan_fit_test_kit                                                    float64
# ipc_ppe_plan_contingency_for_shortages                                       float64
# ipc_wcd_colour_coded_bins                                                    float64
# ipc_wcd_clinical_waste_bags                                                  float64
# ipc_wcd_laundry_receptacles_at_patient_rooms                                 float64
# ipc_wcd_incinerator                                                          float64
# ipc_wash_clean_running_water                                                 float64
# ipc_wash_hand_soap                                                           float64
# ipc_wash_liquid_soap                                                         float64
# ipc_wash_disp_hand_towels                                                    float64
# ipc_wash_alcohol_based_hand_gel                                              float64
# ipc_ds_protocol_facility_disinfection                                        float64
# ipc_ds_protocol_equipment_sterilisation                                      float64
# ipc_ds_environmental_disinfectant                                            float64
# ipc_ds_cleaning_schedule_in_toilets                                          float64
# ipc_ds_protocol_corpse_handling                                              float64
# log_referral_plan                                                            float64
# log_cellphone_landline_swradio                                               float64
# log_tracer_drugs                                                             float64
# log_albendazole                                                              float64
# log_amoxicillin                                                              float64
# log_ampicillin                                                               float64
# log_chlorhexidine_5                                                          float64
# log_chlorhexidine_7                                                          float64
# log_gentamicin                                                               float64
# log_folic                                                                    float64
# log_ferrous_and_folic                                                        float64
# log_compound_sodium                                                          float64
# log_co_trimoxazole_400                                                       float64
# log_co_trimoxazole_200                                                       float64
# log_metronidazole_250                                                        float64
# log_metronidazole_200                                                        float64
# log_methyldopa                                                               float64
# log_magnesium_sulphate                                                       float64
# log_lidocaine                                                                float64
# log_ibuprofen                                                                float64
# log_surgical_spirit                                                          float64
# log_sodium_chloride                                                          float64
# log_povidone                                                                 float64
# log_paracetamol_500                                                          float64
# log_paracetamol_250                                                          float64
# log_ors                                                                      float64
# log_gauze                                                                    float64
# log_cotton_wool                                                              float64
# log_cannula_iv_20                                                            float64
# log_cannula_iv_24                                                            float64
# log_zinc_sulphate                                                            float64
# log_water                                                                    float64
# log_needle_23                                                                float64
# log_needle_21                                                                float64
# log_glove_giving                                                             float64
# log_glove_surgical                                                           float64
# log_glove_gyn                                                                float64
# log_glove_exam                                                               float64
# log_tape                                                                     float64
# log_syringe                                                                  float64
# log_oxytocin                                                                 float64
# log_diazepam                                                                 float64
# log_misoprostol                                                              float64
# log_glucose                                                                  float64
# consultations.head_count.monthly_average_head_counts                         float64
# consultations.general_outpatient.monthly_average_general_outpatient          float64
# consultations.deliveries.monthly_average_deliveries                          float64
# consultations.pent_vaccines.monthly_average_pent_vaccines                    float64
# score_human_resources                                                        float64
# score_max_human_resources                                                    float64
# score_information_education_communication                                    float64
# score_max_information_education_communication                                float64
# score_surveillance                                                           float64
# score_max_surveillance                                                       float64
# score_triage_and_early_recognition                                           float64
# score_max_triage_and_early_recognition                                       float64
# score_chw                                                                    float64
# score_max_chw                                                                float64
# score_isolation                                                              float64
# score_max_isolation                                                          float64
# score_infection_prevention_and_control_ppe                                   float64
# score_max_infection_prevention_and_control_ppe                               float64
# score_infection_prevention_and_control_ppe_plan                              float64
# score_max_infection_prevention_and_control_ppe_plan                          float64
# score_infection_prevention_and_control_waste_collection_and_disposal         float64
# score_max_infection_prevention_and_control_waste_collection_and_disposal     float64
# score_infection_prevention_and_control_water_sanitation_and_hygiene          float64
# score_max_infection_prevention_and_control_water_sanitation_and_hygiene      float64
# score_infection_prevention_and_control_disinfection_and_sterilization        float64
# score_max_infection_prevention_and_control_disinfection_and_sterilization    float64
# score_infection_prevention_and_control                                       float64
# score_max_infection_prevention_and_control                                   float64
# question1.score_logistics_patient_and_sample_transfer                        float64
# question1.score_max_logistics_patient_and_sample_transfer                    float64
# score_total                                                                  float64
# score_max_total                                                              float64
# type_clinic                                                                    int64
# type_community_health_centre                                                   int64
# type_community_health_post                                                     int64
# type_mch_post                                                                  int64
# type_<NA>                                                                      int64
# manage_government_public                                                       int64
# manage_other                                                                   int64
# manage_private_for_profit                                                      int64
# manage_<NA>                                                                    int64
# setting_peri_urban                                                             int64
# setting_rural                                                                  int64
# setting_slum                                                                   int64
# setting_urban                                                                  int64
# setting_<NA>                                                                   int64
# dtype: object

# %%
num_cols = []
for col in df.columns:
    name_parts = col.split('.')
    if len(re.findall('number_', name_parts[-1]))!=0 or name_parts[-1][:6]=='month_' or name_parts[-1][:15]=='monthly_average' or name_parts[-1][:6]=='score_':
        num_cols.append(col)
num_cols
# Out:
# ['capacity.number_consultation_rooms',
#  'capacity.number_inpatient_beds',
#  'capacity.number_maternity_beds',
#  'cho_number_in_post',
#  'cho_number_present_at_visit',
#  'cht_number_in_post',
#  'cht_number_present_at_visit',
#  'cha_number_in_post',
#  'cha_number_present_at_visit',
#  'cm_number_in_post',
#  'cm_number_present_at_visit',
#  'sechn_number_in_post',
#  'sechn_number_present_at_visit',
#  'lab_tech_number_in_post',
#  'lab_tech_number_present_at_visit',
#  'mch_aides_number_in_post',
#  'mch_aides_number_present_at_visit',
#  'cleaner_porter_number_in_post',
#  'cleaner_porter_number_present_at_visit',
#  'other_number_in_post',
#  'other_number_present_at_visit',
#  'consultations.head_count.month_1',
#  'consultations.head_count.month_2',
#  'consultations.head_count.month_3',
#  'consultations.head_count.month_4',
#  'consultations.general_outpatient.month_1',
#  'consultations.general_outpatient.month_2',
#  'consultations.general_outpatient.month_3',
#  'consultations.general_outpatient.month_4',
#  'consultations.deliveries.month_1',
#  'consultations.deliveries.month_2',
#  'consultations.deliveries.month_3',
#  'consultations.deliveries.month_4',
#  'consultations.pent_vaccines.month_1',
#  'consultations.pent_vaccines.month_2',
#  'consultations.pent_vaccines.month_3',
#  'consultations.pent_vaccines.month_4',
#  'consultations.head_count.monthly_average_head_counts',
#  'consultations.general_outpatient.monthly_average_general_outpatient',
#  'consultations.deliveries.monthly_average_deliveries',
#  'consultations.pent_vaccines.monthly_average_pent_vaccines',
#  'score_human_resources',
#  'score_max_human_resources',
#  'score_information_education_communication',
#  'score_max_information_education_communication',
#  'score_surveillance',
#  'score_max_surveillance',
#  'score_triage_and_early_recognition',
#  'score_max_triage_and_early_recognition',
#  'score_chw',
#  'score_max_chw',
#  'score_isolation',
#  'score_max_isolation',
#  'score_infection_prevention_and_control_ppe',
#  'score_max_infection_prevention_and_control_ppe',
#  'score_infection_prevention_and_control_ppe_plan',
#  'score_max_infection_prevention_and_control_ppe_plan',
#  'score_infection_prevention_and_control_waste_collection_and_disposal',
#  'score_max_infection_prevention_and_control_waste_collection_and_disposal',
#  'score_infection_prevention_and_control_water_sanitation_and_hygiene',
#  'score_max_infection_prevention_and_control_water_sanitation_and_hygiene',
#  'score_infection_prevention_and_control_disinfection_and_sterilization',
#  'score_max_infection_prevention_and_control_disinfection_and_sterilization',
#  'score_infection_prevention_and_control',
#  'score_max_infection_prevention_and_control',
#  'question1.score_logistics_patient_and_sample_transfer',
#  'question1.score_max_logistics_patient_and_sample_transfer',
#  'score_total',
#  'score_max_total']

# %%
df.mean(numeric_only=True)
# Out:
# facility_gps_lat                                                               9.731000
# facility_gps_lon                                                              13.066807
# facility_type_other                                                                 NaN
# capacity.number_consultation_rooms                                             1.769231
# capacity.number_inpatient_beds                                                 2.269231
# capacity.number_maternity_beds                                                 2.469231
# cho_number_in_post                                                             0.723077
# cho_number_present_at_visit                                                    0.407692
# cht_number_in_post                                                             0.200000
# cht_number_present_at_visit                                                    0.169231
# cha_number_in_post                                                             0.415385
# cha_number_present_at_visit                                                    0.292308
# cm_number_in_post                                                              0.453846
# cm_number_present_at_visit                                                     0.330769
# sechn_number_in_post                                                           1.269231
# sechn_number_present_at_visit                                                  0.792308
# lab_tech_number_in_post                                                        0.300000
# lab_tech_number_present_at_visit                                               0.238462
# mch_aides_number_in_post                                                       2.169231
# mch_aides_number_present_at_visit                                              1.546154
# cleaner_porter_number_in_post                                                  0.969231
# cleaner_porter_number_present_at_visit                                         0.646154
# other_number_in_post                                                           1.892308
# other_number_present_at_visit                                                  0.776923
# consultations.head_count.month_1                                             467.944000
# consultations.head_count.month_2                                             455.488000
# consultations.head_count.month_3                                             434.328000
# consultations.head_count.month_4                                             395.816000
# consultations.general_outpatient.month_1                                     264.592000
# consultations.general_outpatient.month_2                                     251.392000
# consultations.general_outpatient.month_3                                     248.384000
# consultations.general_outpatient.month_4                                     226.256000
# consultations.deliveries.month_1                                              13.256000
# consultations.deliveries.month_2                                              12.680000
# consultations.deliveries.month_3                                              16.624000
# consultations.deliveries.month_4                                              12.064000
# consultations.pent_vaccines.month_1                                           17.960000
# consultations.pent_vaccines.month_2                                           17.384000
# consultations.pent_vaccines.month_3                                           21.600000
# consultations.pent_vaccines.month_4                                           19.000000
# hr_focal_point                                                                 0.776000
# hr_staff_received_info                                                         1.540984
# hr_healthcare_provider_training                                                0.709677
# hr_healthcare_provider_revised_training                                        0.540323
# hr_daily_staff_list                                                            1.349593
# surv_procedure_for_notification                                                1.322314
# surv_official_case_definition                                                  0.743802
# surv_hotline_number                                                            1.842975
# surv_timely_data_reported_to_district                                          1.958678
# ter_screening_area_set_up                                                      0.894309
# ter_symptom_screening_questionnaires                                           0.479675
# ter_temperature_measurement_at_triage                                          1.048780
# ter_physical_distancing_in_waiting                                             1.325203
# ter_separate_waiting_for_symptomatic                                           0.658333
# chw_trained_precautions                                                        1.065574
# chw_trained_community_service                                                  1.032787
# chw_drugs                                                                      1.082645
# chw_gloves                                                                     1.115702
# chw_masks                                                                      0.770492
# chw_iec_materials                                                              0.652893
# iso_designated_isolation_for_suspected                                         0.586777
# iso_distance_between_patients_in_waiting                                       1.198347
# iso_distance_between_patient_beds                                              1.115702
# iso_transfer_referral_protocol                                                 1.429752
# ipc_ppe_medical_masks                                                          0.965517
# ipc_ppe_disp_surgical_masks                                                    0.991304
# ipc_ppe_eye_protection                                                         1.043478
# ipc_ppe_examination_gloves                                                     1.407080
# ipc_ppe_surgical_gloves                                                        1.026316
# ipc_ppe_long_cuffed_gloves                                                     0.858407
# ipc_ppe_heavy_duty_gloves                                                      0.535088
# ipc_ppe_long_sleeved_gown                                                      0.921053
# ipc_ppe_waterproof_aprons                                                      1.254386
# ipc_ppe_plan_staff_trained_on_ppe                                              1.059829
# ipc_ppe_plan_ppe_poster_displayed                                              0.854701
# ipc_ppe_plan_fit_test_kit                                                      0.384615
# ipc_ppe_plan_contingency_for_shortages                                         0.820513
# ipc_wcd_colour_coded_bins                                                      1.095652
# ipc_wcd_clinical_waste_bags                                                    1.189655
# ipc_wcd_laundry_receptacles_at_patient_rooms                                   0.356522
# ipc_wcd_incinerator                                                            1.137931
# ipc_wash_clean_running_water                                                   1.517241
# ipc_wash_hand_soap                                                             0.811966
# ipc_wash_liquid_soap                                                           0.991379
# ipc_wash_disp_hand_towels                                                      0.146552
# ipc_wash_alcohol_based_hand_gel                                                0.551724
# ipc_ds_protocol_facility_disinfection                                          0.871795
# ipc_ds_protocol_equipment_sterilisation                                        1.000000
# ipc_ds_environmental_disinfectant                                              0.725664
# ipc_ds_cleaning_schedule_in_toilets                                            0.846154
# ipc_ds_protocol_corpse_handling                                                0.421053
# log_referral_plan                                                              1.555556
# log_cellphone_landline_swradio                                                 1.067797
# log_tracer_drugs                                                               1.304348
# log_albendazole                                                                1.316239
# log_amoxicillin                                                                1.389831
# log_ampicillin                                                                 0.865546
# log_chlorhexidine_5                                                            0.906780
# log_chlorhexidine_7                                                            0.578431
# log_gentamicin                                                                 1.113043
# log_folic                                                                      0.666667
# log_ferrous_and_folic                                                          0.336283
# log_compound_sodium                                                            1.131579
# log_co_trimoxazole_400                                                         1.327586
# log_co_trimoxazole_200                                                         0.568966
# log_metronidazole_250                                                          1.344828
# log_metronidazole_200                                                          0.403509
# log_methyldopa                                                                 1.427350
# log_magnesium_sulphate                                                         1.530973
# log_lidocaine                                                                  1.000000
# log_ibuprofen                                                                  1.307692
# log_surgical_spirit                                                            1.282051
# log_sodium_chloride                                                            1.358974
# log_povidone                                                                   1.344828
# log_paracetamol_500                                                            1.310345
# log_paracetamol_250                                                            0.356522
# log_ors                                                                        1.775862
# log_gauze                                                                      0.715517
# log_cotton_wool                                                                1.598291
# log_cannula_iv_20                                                              1.111111
# log_cannula_iv_24                                                              1.086207
# log_zinc_sulphate                                                              1.508621
# log_water                                                                      1.129310
# log_needle_23                                                                  0.931034
# log_needle_21                                                                  0.782609
# log_glove_giving                                                               1.600000
# log_glove_surgical                                                             0.902655
# log_glove_gyn                                                                  0.956522
# log_glove_exam                                                                 1.373913
# log_tape                                                                       0.931624
# log_syringe                                                                    1.243478
# log_oxytocin                                                                   1.486957
# log_diazepam                                                                   1.535088
# log_misoprostol                                                                0.219298
# log_glucose                                                                    0.267857
# consultations.head_count.monthly_average_head_counts                         438.394000
# consultations.general_outpatient.monthly_average_general_outpatient          247.656000
# consultations.deliveries.monthly_average_deliveries                           13.628000
# consultations.pent_vaccines.monthly_average_pent_vaccines                     18.966000
# score_human_resources                                                          2.400794
# score_max_human_resources                                                      5.000000
# score_information_education_communication                                      4.438017
# score_max_information_education_communication                                  7.000000
# score_surveillance                                                             2.909836
# score_max_surveillance                                                         4.000000
# score_triage_and_early_recognition                                             2.177419
# score_max_triage_and_early_recognition                                         5.000000
# score_chw                                                                      2.270161
# score_max_chw                                                                  6.000000
# score_isolation                                                                2.112903
# score_max_isolation                                                            4.000000
# score_infection_prevention_and_control_ppe                                     4.306723
# score_max_infection_prevention_and_control_ppe                                 9.000000
# score_infection_prevention_and_control_ppe_plan                                1.533613
# score_max_infection_prevention_and_control_ppe_plan                            4.000000
# score_infection_prevention_and_control_waste_collection_and_disposal           1.823529
# score_max_infection_prevention_and_control_waste_collection_and_disposal       4.000000
# score_infection_prevention_and_control_water_sanitation_and_hygiene            1.962185
# score_max_infection_prevention_and_control_water_sanitation_and_hygiene        5.000000
# score_infection_prevention_and_control_disinfection_and_sterilization          1.462185
# score_max_infection_prevention_and_control_disinfection_and_sterilization      5.000000
# score_infection_prevention_and_control                                        11.067227
# score_max_infection_prevention_and_control                                    27.000000
# question1.score_logistics_patient_and_sample_transfer                         22.051282
# question1.score_max_logistics_patient_and_sample_transfer                     44.000000
# score_total                                                                   45.294574
# score_max_total                                                               93.201550
# type_clinic                                                                    0.007576
# type_community_health_centre                                                   0.287879
# type_community_health_post                                                     0.287879
# type_mch_post                                                                  0.401515
# type_<NA>                                                                      0.015152
# manage_government_public                                                       0.969697
# manage_other                                                                   0.007576
# manage_private_for_profit                                                      0.007576
# manage_<NA>                                                                    0.015152
# setting_peri_urban                                                             0.674242
# setting_rural                                                                  0.159091
# setting_slum                                                                   0.060606
# setting_urban                                                                  0.121212
# setting_<NA>                                                                   0.015152
# dtype: float64

# %% [markdown]
# Let's check for any super weird outliers.

# %%
is_outlier = (df[num_cols] - df[num_cols].mean()).abs() > 3*df[num_cols].std()
for col in num_cols:
    if is_outlier[col].any()==True:
        print('Col',col)
        print(df[is_outlier[col]==True][col])
# Out:
# Col capacity.number_consultation_rooms
# 103    12.0
# Name: capacity.number_consultation_rooms, dtype: float64
# Col capacity.number_inpatient_beds
# 70     12.0
# 124    11.0
# Name: capacity.number_inpatient_beds, dtype: float64
# Col capacity.number_maternity_beds
# 103    100.0
# Name: capacity.number_maternity_beds, dtype: float64
# Col cho_number_in_post
# 28      7.0
# 66      8.0
# 84     15.0
# 103    12.0
# Name: cho_number_in_post, dtype: float64
# Col cho_number_present_at_visit
# 84     12.0
# 103    12.0
# Name: cho_number_present_at_visit, dtype: float64
# Col cht_number_in_post
# 67      4.0
# 84      4.0
# 103    12.0
# Name: cht_number_in_post, dtype: float64
# Col cht_number_present_at_visit
# 103    12.0
# Name: cht_number_present_at_visit, dtype: float64
# Col cha_number_in_post
# 103    12.0
# 120     5.0
# Name: cha_number_in_post, dtype: float64
# Col cha_number_present_at_visit
# 103    12.0
# Name: cha_number_present_at_visit, dtype: float64
# Col cm_number_in_post
# 103    12.0
# Name: cm_number_in_post, dtype: float64
# Col cm_number_present_at_visit
# 103    12.0
# Name: cm_number_present_at_visit, dtype: float64
# Col sechn_number_in_post
# 38      8.0
# 45     10.0
# 103    12.0
# Name: sechn_number_in_post, dtype: float64
# Col sechn_number_present_at_visit
# 103    12.0
# 107     6.0
# 118     6.0
# Name: sechn_number_present_at_visit, dtype: float64
# Col lab_tech_number_in_post
# 18      4.0
# 103    12.0
# Name: lab_tech_number_in_post, dtype: float64
# Col lab_tech_number_present_at_visit
# 103    12.0
# Name: lab_tech_number_present_at_visit, dtype: float64
# Col mch_aides_number_in_post
# 16      7.0
# 18      7.0
# 71      8.0
# 103    12.0
# Name: mch_aides_number_in_post, dtype: float64
# Col mch_aides_number_present_at_visit
# 103    12.0
# Name: mch_aides_number_present_at_visit, dtype: float64
# Col cleaner_porter_number_in_post
# 103    12.0
# Name: cleaner_porter_number_in_post, dtype: float64
# Col cleaner_porter_number_present_at_visit
# 103    12.0
# Name: cleaner_porter_number_present_at_visit, dtype: float64
# Col other_number_in_post
# 1     13.0
# 2     18.0
# 19    16.0
# 27    17.0
# Name: other_number_in_post, dtype: float64
# Col other_number_present_at_visit
# 9       6.0
# 24      7.0
# 50      6.0
# 86      6.0
# 103    12.0
# Name: other_number_present_at_visit, dtype: float64
# Col consultations.head_count.month_1
# 64     2261.0
# 124    1840.0
# Name: consultations.head_count.month_1, dtype: float64
# Col consultations.head_count.month_2
# 64     2234.0
# 124    2330.0
# Name: consultations.head_count.month_2, dtype: float64
# Col consultations.head_count.month_3
# 64     1724.0
# 124    2309.0
# Name: consultations.head_count.month_3, dtype: float64
# Col consultations.head_count.month_4
# 64     1942.0
# 122    1428.0
# 124    1658.0
# Name: consultations.head_count.month_4, dtype: float64
# Col consultations.general_outpatient.month_1
# 100    1080.0
# 124    1257.0
# 128     914.0
# Name: consultations.general_outpatient.month_1, dtype: float64
# Col consultations.general_outpatient.month_2
# 61     1048.0
# 100    1193.0
# 124    1197.0
# Name: consultations.general_outpatient.month_2, dtype: float64
# Col consultations.general_outpatient.month_3
# 20      888.0
# 61      965.0
# 124    1182.0
# Name: consultations.general_outpatient.month_3, dtype: float64
# Col consultations.general_outpatient.month_4
# 61     861.0
# 75     759.0
# 117    913.0
# 124    803.0
# Name: consultations.general_outpatient.month_4, dtype: float64
# Col consultations.deliveries.month_1
# 30     40.0
# 38     40.0
# 100    40.0
# Name: consultations.deliveries.month_1, dtype: float64
# Col consultations.deliveries.month_2
# 30    37.0
# 38    41.0
# Name: consultations.deliveries.month_2, dtype: float64
# Col consultations.deliveries.month_3
# 102    415.0
# Name: consultations.deliveries.month_3, dtype: float64
# Col consultations.deliveries.month_4
# 4    58.0
# Name: consultations.deliveries.month_4, dtype: float64
# Col consultations.pent_vaccines.month_1
# 4      120.0
# 100     89.0
# Name: consultations.pent_vaccines.month_1, dtype: float64
# Col consultations.pent_vaccines.month_2
# 4     125.0
# 38     70.0
# Name: consultations.pent_vaccines.month_2, dtype: float64
# Col consultations.pent_vaccines.month_3
# 4    639.0
# Name: consultations.pent_vaccines.month_3, dtype: float64
# Col consultations.pent_vaccines.month_4
# 4    588.0
# Name: consultations.pent_vaccines.month_4, dtype: float64
# Col consultations.head_count.monthly_average_head_counts
# 64     2040.25
# 124    2034.25
# Name: consultations.head_count.monthly_average_head_counts, dtype: float64
# Col consultations.general_outpatient.monthly_average_general_outpatient
# 61      905.25
# 100     825.50
# 124    1109.75
# Name: consultations.general_outpatient.monthly_average_general_outpatient, dtype: float64
# Col consultations.deliveries.monthly_average_deliveries
# 38      51.25
# 102    110.00
# Name: consultations.deliveries.monthly_average_deliveries, dtype: float64
# Col consultations.pent_vaccines.monthly_average_pent_vaccines
# 4    368.0
# Name: consultations.pent_vaccines.monthly_average_pent_vaccines, dtype: float64
# Col score_surveillance
# 8    0.0
# Name: score_surveillance, dtype: float64
# Col score_max_total
# 48      0.0
# 53      6.0
# 84      0.0
# 88     13.0
# 89      5.0
# 104     9.0
# Name: score_max_total, dtype: float64

# %% [markdown]
# None of the outliers look too wild.

# %%
num_cols_no_score = []
for col in num_cols:
    if len(re.findall('score',col))!=0:
        pass
    else:
        num_cols_no_score.append(col)
corr = df[num_cols_no_score].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b637f_row0_col0, #T_b637f_row1_col1, #T_b637f_row2_col2, #T_b637f_row3_col3, #T_b637f_row4_col4, #T_b637f_row5_col5, #T_b637f_row6_col6, #T_b637f_row7_col7, #T_b637f_row8_col8, #T_b637f_row9_col9, #T_b637f_row10_col10, #T_b637f_row11_col11, #T_b637f_row12_col12, #T_b637f_row13_col13, #T_b637f_row14_col14, #T_b637f_row15_col15, #T_b637f_row16_col16, #T_b637f_row17_col17, #T_b637f_row18_col18, #T_b637f_row19_col19, #T_b637f_row20_col20, #T_b637f_row21_col21, #T_b637f_row22_col22, #T_b637f_row23_col23, #T_b637f_row24_col24, #T_b637f_row25_col25, #T_b637f_row26_col26, #T_b637f_row27_col27, #T_b637f_row28_col28, #T_b637f_row29_col29, #T_b637f_row30_col30, #T_b637f_row31_col31, #T_b637f_row32_col32, #T_b637f_row33_col33, #T_b637f_row34_col34, #T_b637f_row35_col35, #T_b637f_row36_col36, #T_b637f_row37_col37, #T_b637f_row38_col38, #T_b637f_row39_col39, #T_b637f_row40_col40 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col1, #T_b637f_row28_col39, #T_b637f_row30_col24 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_b637f_row0_col2, #T_b637f_row5_col17, #T_b637f_row23_col26, #T_b637f_row25_col37, #T_b637f_row26_col37, #T_b637f_row37_col27 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_b637f_row0_col3, #T_b637f_row1_col23, #T_b637f_row2_col11, #T_b637f_row19_col17 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b637f_row0_col4, #T_b637f_row3_col14, #T_b637f_row3_col17 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b637f_row0_col5, #T_b637f_row3_col9, #T_b637f_row10_col3, #T_b637f_row11_col10, #T_b637f_row32_col35, #T_b637f_row37_col28, #T_b637f_row39_col29 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_b637f_row0_col6, #T_b637f_row22_col25, #T_b637f_row26_col21 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_b637f_row0_col7, #T_b637f_row3_col6, #T_b637f_row7_col16, #T_b637f_row10_col20, #T_b637f_row12_col4, #T_b637f_row20_col18, #T_b637f_row32_col36 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b637f_row0_col8, #T_b637f_row5_col7, #T_b637f_row7_col17, #T_b637f_row22_col38 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_b637f_row0_col9, #T_b637f_row4_col9, #T_b637f_row4_col10, #T_b637f_row7_col5, #T_b637f_row10_col12, #T_b637f_row13_col7, #T_b637f_row13_col18, #T_b637f_row17_col5 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_b637f_row0_col10, #T_b637f_row2_col16, #T_b637f_row9_col18, #T_b637f_row26_col22 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b637f_row0_col11, #T_b637f_row13_col15, #T_b637f_row20_col10, #T_b637f_row30_col39 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_b637f_row0_col12, #T_b637f_row12_col5, #T_b637f_row17_col4, #T_b637f_row24_col28 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b637f_row0_col13, #T_b637f_row7_col18, #T_b637f_row9_col12, #T_b637f_row12_col9 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_b637f_row0_col14, #T_b637f_row9_col0, #T_b637f_row17_col9, #T_b637f_row18_col13, #T_b637f_row22_col26, #T_b637f_row37_col26 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_b637f_row0_col15, #T_b637f_row11_col34, #T_b637f_row20_col12, #T_b637f_row36_col29 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b637f_row0_col16, #T_b637f_row15_col7 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_b637f_row0_col17, #T_b637f_row9_col16, #T_b637f_row16_col10, #T_b637f_row34_col29, #T_b637f_row36_col32 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_b637f_row0_col18, #T_b637f_row7_col0, #T_b637f_row12_col7, #T_b637f_row15_col13, #T_b637f_row32_col39 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_b637f_row0_col19, #T_b637f_row1_col28, #T_b637f_row12_col1, #T_b637f_row14_col1, #T_b637f_row19_col14, #T_b637f_row21_col39, #T_b637f_row34_col11, #T_b637f_row39_col24 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b637f_row0_col20, #T_b637f_row7_col3, #T_b637f_row15_col3, #T_b637f_row39_col33 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_b637f_row0_col21, #T_b637f_row15_col34, #T_b637f_row18_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b637f_row0_col22, #T_b637f_row0_col25, #T_b637f_row19_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b637f_row0_col23, #T_b637f_row0_col39, #T_b637f_row1_col16, #T_b637f_row38_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b637f_row0_col24, #T_b637f_row7_col22, #T_b637f_row7_col30, #T_b637f_row12_col34, #T_b637f_row19_col3, #T_b637f_row27_col40, #T_b637f_row31_col1, #T_b637f_row34_col31 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col26, #T_b637f_row0_col38, #T_b637f_row1_col32, #T_b637f_row9_col31, #T_b637f_row15_col30 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b637f_row0_col27, #T_b637f_row19_col10, #T_b637f_row19_col13, #T_b637f_row35_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b637f_row0_col28, #T_b637f_row12_col33, #T_b637f_row15_col26, #T_b637f_row15_col29, #T_b637f_row31_col40, #T_b637f_row38_col19 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col29, #T_b637f_row0_col31, #T_b637f_row31_col30, #T_b637f_row31_col32, #T_b637f_row32_col31 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b637f_row0_col30, #T_b637f_row31_col33 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b637f_row0_col32, #T_b637f_row9_col27, #T_b637f_row12_col40, #T_b637f_row14_col31, #T_b637f_row16_col11, #T_b637f_row31_col27 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col33, #T_b637f_row13_col30, #T_b637f_row40_col38 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col34, #T_b637f_row15_col39, #T_b637f_row27_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b637f_row0_col35, #T_b637f_row4_col1, #T_b637f_row9_col23, #T_b637f_row9_col29, #T_b637f_row12_col32, #T_b637f_row15_col33, #T_b637f_row15_col37, #T_b637f_row19_col26, #T_b637f_row19_col28, #T_b637f_row38_col31, #T_b637f_row40_col22, #T_b637f_row40_col31 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col36, #T_b637f_row3_col33, #T_b637f_row8_col21, #T_b637f_row22_col31, #T_b637f_row22_col40, #T_b637f_row28_col20, #T_b637f_row31_col34, #T_b637f_row35_col9, #T_b637f_row36_col22, #T_b637f_row40_col19 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b637f_row0_col37, #T_b637f_row15_col32, #T_b637f_row35_col11 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b637f_row0_col40, #T_b637f_row12_col19, #T_b637f_row15_col21, #T_b637f_row20_col15, #T_b637f_row39_col11, #T_b637f_row40_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b637f_row1_col0, #T_b637f_row25_col33, #T_b637f_row27_col29, #T_b637f_row29_col25, #T_b637f_row30_col22, #T_b637f_row30_col33, #T_b637f_row40_col29 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b637f_row1_col2, #T_b637f_row7_col19, #T_b637f_row11_col21, #T_b637f_row11_col37, #T_b637f_row14_col19, #T_b637f_row25_col32, #T_b637f_row27_col39, #T_b637f_row32_col25 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b637f_row1_col3, #T_b637f_row11_col32, #T_b637f_row19_col2, #T_b637f_row20_col0, #T_b637f_row22_col1, #T_b637f_row31_col29, #T_b637f_row39_col21 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b637f_row1_col4, #T_b637f_row1_col7, #T_b637f_row1_col12, #T_b637f_row8_col19, #T_b637f_row11_col1, #T_b637f_row23_col34 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b637f_row1_col5, #T_b637f_row9_col19, #T_b637f_row13_col1, #T_b637f_row19_col6, #T_b637f_row21_col34, #T_b637f_row22_col39, #T_b637f_row24_col34, #T_b637f_row25_col1, #T_b637f_row39_col22 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b637f_row1_col6, #T_b637f_row1_col11, #T_b637f_row12_col15, #T_b637f_row24_col39, #T_b637f_row39_col37 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_b637f_row1_col8, #T_b637f_row16_col0, #T_b637f_row34_col25 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_b637f_row1_col9, #T_b637f_row1_col33, #T_b637f_row36_col30, #T_b637f_row38_col33 {
#   background-color: #d5dbe5;
#   color: #0000

# %% [markdown]
# There are some obvious correlations above, e.g. numbers of consultations are correlated with one another.
