# %% [markdown]
# # Cleaning and exploring data for Macro-Eyes

# %%
import os
import pathlib
from pathlib import Path 
import pandas as pd
import numpy as np
import re

# %% [markdown]
# To do:
# * Remove duplicate rows
# * Check for different text referring to same facility eg 'hospital' vs 'chp'

# %% [markdown]
# It will be helpful later to display all the columns:

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %% [markdown]
# ## Read in raw data

# %%
df_raw = pd.read_excel('Health Facility Assessment (1).xlsx',index_col=0, usecols='B:GW')
df = df_raw.copy()
df=df.iloc[:50,:]

# %% [markdown]
# ## Delete empty columns

# %%
# the columns whose names end with 'choice_labels' are empty, so we can delete them
choice_label_cols = []
for col in df.columns:
    if len((re.findall('\.choice_labels',col)))!=0:
        choice_label_cols.append(col)

df = df.drop(choice_label_cols,axis=1)

# %% [markdown]
# ## Shorten column names

# %% [markdown]
# Let's start by displaying the column names:

# %%
cols = list(df.columns)
print(*cols,sep='\n')
# Out:
# form.health_centre_information.facility_name
# form.facility_gps
# form.health_centre_information.location_information.region_province
# form.health_centre_information.location_information.district
# form.health_centre_information.location_information.chiefdom
# form.health_centre_information.location_information.facility_location
# form.health_centre_information.facility_type
# form.health_centre_information.facility_type_other
# form.health_centre_information.managing_authority
# form.health_centre_information.managing_authority_other
# form.health_centre_information.setting
# form.health_centre_information.outpatient_only
# form.health_centre_information.capacity.number_consultation_rooms
# form.health_centre_information.capacity.number_inpatient_beds
# form.health_centre_information.capacity.number_maternity_beds
# form.health_centre_information.group_number_employed.list_community_health_officer.cho_number_in_post
# form.health_centre_information.group_number_employed.list_community_health_officer.cho_number_present_at_visit
# form.health_centre_information.group_number_employed.list_community_health_technician.cht_number_in_post
# form.health_centre_information.group_number_employed.list_community_health_technician.cht_number_present_at_visit
# form.health_centre_information.group_number_employed.list_community_health_assistant.cha_number_in_post
# form.health_centre_information.group_number_employed.list_community_health_assistant.cha_number_present_at_visit
# form.health_centre_information.group_number_employed.list_community_midwives.cm_number_in_post
# form.health_centre_information.group_number_employed.list_community_midwives.cm_number_present_at_visit
# form.health_centre_information.group_number_employed.list_sechn.sechn_number_in_post
# form.health_centre_information.group_number_employed.list_sechn.sechn_number_present_at_visit
# form.health_centre_information.group_number_employed.list_laboratory_technicians.lab_tech_number_in_post
# form.health_centre_information.group_number_employed.list_laboratory_technicians.lab_tech_number_present_at_visit
# form.health_centre_information.group_number_employed.list_mch_aides.mch_aides_number_in_post
# form.health_centre_information.group_number_employed.list_mch_aides.mch_aides_number_present_at_visit
# form.health_centre_information.group_number_employed.list_cleaner_porter.cleaner_porter_number_in_post
# form.health_centre_information.group_number_employed.list_cleaner_porter.cleaner_porter_number_present_at_visit
# form.health_centre_information.group_number_employed.list_other.other_number_in_post
# form.health_centre_information.group_number_employed.list_other.other_number_present_at_visit
# form.health_centre_information.group_number_employed.list_other.other_staff_cadre
# form.sections_to_review
# form.consultations.head_count.month_1
# form.consultations.head_count.month_2
# form.consultations.head_count.month_3
# form.consultations.head_count.month_4
# form.consultations.general_outpatient.month_1
# form.consultations.general_outpatient.month_2
# form.consultations.general_outpatient.month_3
# form.consultations.general_outpatient.month_4
# form.consultations.deliveries.month_1
# form.consultations.deliveries.month_2
# form.consultations.deliveries.month_3
# form.consultations.deliveries.month_4
# form.consultations.pent_vaccines.month_1
# form.consultations.pent_vaccines.month_2
# form.consultations.pent_vaccines.month_3
# form.consultations.pent_vaccines.month_4
# form.ql_human_resources.hr_focal_point
# form.ql_human_resources.hr_staff_received_info
# form.ql_human_resources.hr_healthcare_provider_training
# form.ql_human_resources.hr_healthcare_provider_revised_training
# form.ql_human_resources.hr_daily_staff_list
# form.ql_information_education_communication.iec_handwashing_procedure
# form.ql_information_education_communication.iec_physical_distancing
# form.ql_information_education_communication.iec_covering_nose_mouth
# form.ql_information_education_communication.iec_early_symptom_recognition
# form.ql_information_education_communication.iec_when_facility_vs_home
# form.ql_information_education_communication.iec_rational_ppe_use
# form.ql_information_education_communication.iec_helpline_number
# form.ql_surveillance.surv_procedure_for_notification
# form.ql_surveillance.surv_official_case_definition
# form.ql_surveillance.surv_hotline_number
# form.ql_surveillance.surv_timely_data_reported_to_district
# form.ql_triage_and_early_recognition.ter_screening_area_set_up
# form.ql_triage_and_early_recognition.ter_symptom_screening_questionnaires
# form.ql_triage_and_early_recognition.ter_temperature_measurement_at_triage
# form.ql_triage_and_early_recognition.ter_physical_distancing_in_waiting
# form.ql_triage_and_early_recognition.ter_separate_waiting_for_symptomatic
# form.ql_chw.chw_trained_precautions
# form.ql_chw.chw_trained_community_service
# form.ql_chw.chw_drugs
# form.ql_chw.chw_gloves
# form.ql_chw.chw_masks
# form.ql_chw.chw_iec_materials
# form.ql_isolation_physical_distancing.iso_designated_isolation_for_suspected
# form.ql_isolation_physical_distancing.iso_distance_between_patients_in_waiting
# form.ql_isolation_physical_distancing.iso_distance_between_patient_beds
# form.ql_isolation_physical_distancing.iso_transfer_referral_protocol
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_medical_masks
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_disp_surgical_masks
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_eye_protection
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_examination_gloves
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_surgical_gloves
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_long_cuffed_gloves
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_heavy_duty_gloves
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_long_sleeved_gown
# form.grp_infection_prevention_and_control.ql_ppe.ipc_ppe_waterproof_aprons
# form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_staff_trained_on_ppe
# form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_ppe_poster_displayed
# form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_fit_test_kit
# form.grp_infection_prevention_and_control.ql_ppe_plan.ipc_ppe_plan_contingency_for_shortages
# form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_colour_coded_bins
# form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_clinical_waste_bags
# form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_laundry_receptacles_at_patient_rooms
# form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.ipc_wcd_incinerator
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_clean_running_water
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_hand_soap
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_liquid_soap
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_disp_hand_towels
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.ipc_wash_alcohol_based_hand_gel
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_protocol_facility_disinfection
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_protocol_equipment_sterilisation
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_environmental_disinfectant
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_cleaning_schedule_in_toilets
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.ipc_ds_protocol_corpse_handling
# form.ql_logistics_patient_and_sample_transfer.log_referral_plan
# form.ql_logistics_patient_and_sample_transfer.log_cellphone_landline_swradio
# form.ql_logistics_patient_and_sample_transfer.log_tracer_drugs
# form.ql_logistics_patient_and_sample_transfer.log_albendazole
# form.ql_logistics_patient_and_sample_transfer.log_amoxicillin
# form.ql_logistics_patient_and_sample_transfer.log_ampicillin
# form.ql_logistics_patient_and_sample_transfer.log_chlorhexidine_5
# form.question10.log_chlorhexidine_7
# form.question10.log_gentamicin
# form.question10.log_folic
# form.question10.log_ferrous_and_folic
# form.question10.log_compound_sodium
# form.question10.log_co_trimoxazole_400
# form.question10.log_co_trimoxazole_200
# form.question6.log_metronidazole_250
# form.question6.log_metronidazole_200
# form.question6.log_methyldopa
# form.question6.log_magnesium_sulphate
# form.question6.log_lidocaine
# form.question6.log_ibuprofen
# form.question2.log_surgical_spirit
# form.question2.log_sodium_chloride
# form.question2.log_povidone
# form.question2.log_paracetamol_500
# form.question2.log_paracetamol_250
# form.question2.log_ors
# form.question7.log_gauze
# form.question7.log_cotton_wool
# form.question7.log_cannula_iv_20
# form.question7.log_cannula_iv_24
# form.question7.log_zinc_sulphate
# form.question7.log_water
# form.question4.log_needle_23
# form.question4.log_needle_21
# form.question4.log_glove_giving
# form.question4.log_glove_surgical
# form.question4.log_glove_gyn
# form.question4.log_glove_exam
# form.question1.log_tape
# form.question1.log_syringe
# form.question1.log_oxytocin
# form.question1.log_diazepam
# form.question1.log_misoprostol
# form.question1.log_glucose
# form.consultations.head_count.monthly_average_head_counts
# form.consultations.general_outpatient.monthly_average_general_outpatient
# form.consultations.deliveries.monthly_average_deliveries
# form.consultations.pent_vaccines.monthly_average_pent_vaccines
# form.ql_human_resources.score_human_resources
# form.ql_human_resources.score_max_human_resources
# form.ql_information_education_communication.score_information_education_communication
# form.ql_information_education_communication.score_max_information_education_communication
# form.ql_surveillance.score_surveillance
# form.ql_surveillance.score_max_surveillance
# form.ql_triage_and_early_recognition.score_triage_and_early_recognition
# form.ql_triage_and_early_recognition.score_max_triage_and_early_recognition
# form.ql_chw.score_chw
# form.ql_chw.score_max_chw
# form.ql_isolation_physical_distancing.score_isolation
# form.ql_isolation_physical_distancing.score_max_isolation
# form.grp_infection_prevention_and_control.ql_ppe.score_infection_prevention_and_control_ppe
# form.grp_infection_prevention_and_control.ql_ppe.score_max_infection_prevention_and_control_ppe
# form.grp_infection_prevention_and_control.ql_ppe_plan.score_infection_prevention_and_control_ppe_plan
# form.grp_infection_prevention_and_control.ql_ppe_plan.score_max_infection_prevention_and_control_ppe_plan
# form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.score_infection_prevention_and_control_waste_collection_and_disposal
# form.grp_infection_prevention_and_control.ql_waste_collection_and_disposal.score_max_infection_prevention_and_control_waste_collection_and_disposal
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_infection_prevention_and_control_water_sanitation_and_hygiene
# form.grp_infection_prevention_and_control.ql_water_sanitation_and_hygiene.score_max_infection_prevention_and_control_water_sanitation_and_hygiene
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_infection_prevention_and_control_disinfection_and_sterilization
# form.grp_infection_prevention_and_control.ql_disinfection_and_sterilization.score_max_infection_prevention_and_control_disinfection_and_sterilization
# form.grp_infection_prevention_and_control.score_infection_prevention_and_control
# form.grp_infection_prevention_and_control.score_max_infection_prevention_and_control
# form.question1.score_logistics_patient_and_sample_transfer
# form.question1.score_max_logistics_patient_and_sample_transfer
# form.score_total
# form.score_max_total

# %% [markdown]
# These column names are painfully long to work with, so I will remove some unnecesary words.

# %%
new_cols = []
for i,name in enumerate(cols):
    name = re.sub('form\.','',name)
    name = re.sub('health_centre_information\.','',name)
    name = re.sub('location_information\.','',name)
    name = re.sub('group_number_employed\.','',name)
    name = re.sub('list_.*\.','',name)
    name = re.sub('ql_information_education_communication\.','',name)
    name = re.sub('ql_human_resources\.','',name)
    name = re.sub('ql_surveillance\.','',name)
    name = re.sub('ql_triage_and_early_recognition\.','',name)
    name = re.sub('ql_chw\.','',name)
    name = re.sub('ql_isolation_physical_distancing\.','',name)
    
    # remove everything from 'grp_infection_prevention_and_control.' to the next '.'
    name = re.sub('grp_infection_prevention_and_control\..*\.','',name) 
    # remove any remaining instances of 'grp_infection_prevention_and_control.'
    name = re.sub('grp_infection_prevention_and_control\.','',name) 
    
    # remove everything before the word 'log'
    name = re.sub('.*\.log_','log_',name)
    
    new_cols.append(name)

    print(name)
df.columns = new_cols
# Out:
# facility_name
# facility_gps
# region_province
# district
# chiefdom
# facility_location
# facility_type
# facility_type_other
# managing_authority
# managing_authority_other
# setting
# outpatient_only
# capacity.number_consultation_rooms
# capacity.number_inpatient_beds
# capacity.number_maternity_beds
# cho_number_in_post
# cho_number_present_at_visit
# cht_number_in_post
# cht_number_present_at_visit
# cha_number_in_post
# cha_number_present_at_visit
# cm_number_in_post
# cm_number_present_at_visit
# sechn_number_in_post
# sechn_number_present_at_visit
# lab_tech_number_in_post
# lab_tech_number_present_at_visit
# mch_aides_number_in_post
# mch_aides_number_present_at_visit
# cleaner_porter_number_in_post
# cleaner_porter_number_present_at_visit
# other_number_in_post
# other_number_present_at_visit
# other_staff_cadre
# sections_to_review
# consultations.head_count.month_1
# consultations.head_count.month_2
# consultations.head_count.month_3
# consultations.head_count.month_4
# consultations.general_outpatient.month_1
# consultations.general_outpatient.month_2
# consultations.general_outpatient.month_3
# consultations.general_outpatient.month_4
# consultations.deliveries.month_1
# consultations.deliveries.month_2
# consultations.deliveries.month_3
# consultations.deliveries.month_4
# consultations.pent_vaccines.month_1
# consultations.pent_vaccines.month_2
# consultations.pent_vaccines.month_3
# consultations.pent_vaccines.month_4
# hr_focal_point
# hr_staff_received_info
# hr_healthcare_provider_training
# hr_healthcare_provider_revised_training
# hr_daily_staff_list
# iec_handwashing_procedure
# iec_physical_distancing
# iec_covering_nose_mouth
# iec_early_symptom_recognition
# iec_when_facility_vs_home
# iec_rational_ppe_use
# iec_helpline_number
# surv_procedure_for_notification
# surv_official_case_definition
# surv_hotline_number
# surv_timely_data_reported_to_district
# ter_screening_area_set_up
# ter_symptom_screening_questionnaires
# ter_temperature_measurement_at_triage
# ter_physical_distancing_in_waiting
# ter_separate_waiting_for_symptomatic
# chw_trained_precautions
# chw_trained_community_service
# chw_drugs
# chw_gloves
# chw_masks
# chw_iec_materials
# iso_designated_isolation_for_suspected
# iso_distance_between_patients_in_waiting
# iso_distance_between_patient_beds
# iso_transfer_referral_protocol
# ipc_ppe_medical_masks
# ipc_ppe_disp_surgical_masks
# ipc_ppe_eye_protection
# ipc_ppe_examination_gloves
# ipc_ppe_surgical_gloves
# ipc_ppe_long_cuffed_gloves
# ipc_ppe_heavy_duty_gloves
# ipc_ppe_long_sleeved_gown
# ipc_ppe_waterproof_aprons
# ipc_ppe_plan_staff_trained_on_ppe
# ipc_ppe_plan_ppe_poster_displayed
# ipc_ppe_plan_fit_test_kit
# ipc_ppe_plan_contingency_for_shortages
# ipc_wcd_colour_coded_bins
# ipc_wcd_clinical_waste_bags
# ipc_wcd_laundry_receptacles_at_patient_rooms
# ipc_wcd_incinerator
# ipc_wash_clean_running_water
# ipc_wash_hand_soap
# ipc_wash_liquid_soap
# ipc_wash_disp_hand_towels
# ipc_wash_alcohol_based_hand_gel
# ipc_ds_protocol_facility_disinfection
# ipc_ds_protocol_equipment_sterilisation
# ipc_ds_environmental_disinfectant
# ipc_ds_cleaning_schedule_in_toilets
# ipc_ds_protocol_corpse_handling
# log_referral_plan
# log_cellphone_landline_swradio
# log_tracer_drugs
# log_albendazole
# log_amoxicillin
# log_ampicillin
# log_chlorhexidine_5
# log_chlorhexidine_7
# log_gentamicin
# log_folic
# log_ferrous_and_folic
# log_compound_sodium
# log_co_trimoxazole_400
# log_co_trimoxazole_200
# log_metronidazole_250
# log_metronidazole_200
# log_methyldopa
# log_magnesium_sulphate
# log_lidocaine
# log_ibuprofen
# log_surgical_spirit
# log_sodium_chloride
# log_povidone
# log_paracetamol_500
# log_paracetamol_250
# log_ors
# log_gauze
# log_cotton_wool
# log_cannula_iv_20
# log_cannula_iv_24
# log_zinc_sulphate
# log_water
# log_needle_23
# log_needle_21
# log_glove_giving
# log_glove_surgical
# log_glove_gyn
# log_glove_exam
# log_tape
# log_syringe
# log_oxytocin
# log_diazepam
# log_misoprostol
# log_glucose
# consultations.head_count.monthly_average_head_counts
# consultations.general_outpatient.monthly_average_general_outpatient
# consultations.deliveries.monthly_average_deliveries
# consultations.pent_vaccines.monthly_average_pent_vaccines
# score_human_resources
# score_max_human_resources
# score_information_education_communication
# score_max_information_education_communication
# score_surveillance
# score_max_surveillance
# score_triage_and_early_recognition
# score_max_triage_and_early_recognition
# score_chw
# score_max_chw
# score_isolation
# score_max_isolation
# score_infection_prevention_and_control_ppe
# score_max_infection_prevention_and_control_ppe
# score_infection_prevention_and_control_ppe_plan
# score_max_infection_prevention_and_control_ppe_plan
# score_infection_prevention_and_control_waste_collection_and_disposal
# score_max_infection_prevention_and_control_waste_collection_and_disposal
# score_infection_prevention_and_control_water_sanitation_and_hygiene
# score_max_infection_prevention_and_control_water_sanitation_and_hygiene
# score_infection_prevention_and_control_disinfection_and_sterilization
# score_max_infection_prevention_and_control_disinfection_and_sterilization
# score_infection_prevention_and_control
# score_max_infection_prevention_and_control
# question1.score_logistics_patient_and_sample_transfer
# question1.score_max_logistics_patient_and_sample_transfer
# score_total
# score_max_total

# %% [markdown]
# Abbreviations in the new column names:
# * cho: community health officer
# * cht: community health technician
# * cha: community health assistant
# * cm: community midwives
# * sechn: state enrolled community health nurse
# * mch: maternal and child health
# * hr: human resources
# * iec: information education communication
# * surv: surveillance
# * ter: triage and early recognition
# * chw: community health worker
# * iso: isolation
# * ppe: personal protective equipment
# * ipc: infection prevention and control
# * wcd: waste collection and disposal
# * ds: disinfection and sterilization
# * log: logistics

# %% [markdown]
# ## Some preliminary changes to the data

# %% [markdown]
# There are a few obvious things we can do right off the bat to make the data easier to work with.
#
# Firstly, the missing values in the dataset are indicated by '---'. Explicitly saying that the values are missing is more useful, so we replace the '---' values with np.nan.

# %%
# replace --- values with NA
df = df.replace('---', np.nan, regex=True)

# %% [markdown]
# We can also split the GPS values into latitude and longitude:

# %%
# split GPS values into longitude and latitude
df.insert(loc=1,column = 'facility_gps_lat',value=df['facility_gps'].apply(lambda x: x.split(',')[0]))
df.insert(loc=2,column = 'facility_gps_lon',value=df['facility_gps'].apply(lambda x: x.split(',')[1]))
df = df.drop('facility_gps',axis=1)
# Out:
# /tmp/ipykernel_23591/4057685809.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(loc=1,column = 'facility_gps_lat',value=df['facility_gps'].apply(lambda x: x.split(',')[0]))
# /tmp/ipykernel_23591/4057685809.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(loc=2,column = 'facility_gps_lon',value=df['facility_gps'].apply(lambda x: x.split(',')[1]))

# %% [markdown]
# We can change yes and no values to true and false values:

# %%
# replace 'yes' with True and 'no' with False
df['outpatient_only'] = df['outpatient_only'].apply(lambda x: True if x=='yes' else x)
df['outpatient_only'] = df['outpatient_only'].apply(lambda x: False if x=='no' else x)

# %% [markdown]
# ## Data types

# %% [markdown]
# The dataframe will be easier to use for modeling and to work with in general if the data types for the columns are specified. Let us explore the current data types:

# %%
df.dtypes
# Out:
# facility_name                                                                 object
# facility_gps_lat                                                              object
# facility_gps_lon                                                              object
# region_province                                                               object
# district                                                                      object
# chiefdom                                                                      object
# facility_location                                                             object
# facility_type                                                                 object
# facility_type_other                                                          float64
# managing_authority                                                            object
# managing_authority_other                                                     float64
# setting                                                                       object
# outpatient_only                                                               object
# capacity.number_consultation_rooms                                            object
# capacity.number_inpatient_beds                                                object
# capacity.number_maternity_beds                                                object
# cho_number_in_post                                                            object
# cho_number_present_at_visit                                                   object
# cht_number_in_post                                                            object
# cht_number_present_at_visit                                                   object
# cha_number_in_post                                                            object
# cha_number_present_at_visit                                                   object
# cm_number_in_post                                                             object
# cm_number_present_at_visit                                                    object
# sechn_number_in_post                                                          object
# sechn_number_present_at_visit                                                 object
# lab_tech_number_in_post                                                       object
# lab_tech_number_present_at_visit                                              object
# mch_aides_number_in_post                                                      object
# mch_aides_number_present_at_visit                                             object
# cleaner_porter_number_in_post                                                 object
# cleaner_porter_number_present_at_visit                                        object
# other_number_in_post                                                          object
# other_number_present_at_visit                                                 object
# other_staff_cadre                                                             object
# sections_to_review                                                            object
# consultations.head_count.month_1                                              object
# consultations.head_count.month_2                                              object
# consultations.head_count.month_3                                              object
# consultations.head_count.month_4                                              object
# consultations.general_outpatient.month_1                                      object
# consultations.general_outpatient.month_2                                      object
# consultations.general_outpatient.month_3                                      object
# consultations.general_outpatient.month_4                                      object
# consultations.deliveries.month_1                                              object
# consultations.deliveries.month_2                                              object
# consultations.deliveries.month_3                                              object
# consultations.deliveries.month_4                                              object
# consultations.pent_vaccines.month_1                                           object
# consultations.pent_vaccines.month_2                                           object
# consultations.pent_vaccines.month_3                                           object
# consultations.pent_vaccines.month_4                                           object
# hr_focal_point                                                                object
# hr_staff_received_info                                                        object
# hr_healthcare_provider_training                                               object
# hr_healthcare_provider_revised_training                                       object
# hr_daily_staff_list                                                           object
# iec_handwashing_procedure                                                     object
# iec_physical_distancing                                                       object
# iec_covering_nose_mouth                                                       object
# iec_early_symptom_recognition                                                 object
# iec_when_facility_vs_home                                                     object
# iec_rational_ppe_use                                                          object
# iec_helpline_number                                                           object
# surv_procedure_for_notification                                               object
# surv_official_case_definition                                                 object
# surv_hotline_number                                                           object
# surv_timely_data_reported_to_district                                         object
# ter_screening_area_set_up                                                     object
# ter_symptom_screening_questionnaires                                          object
# ter_temperature_measurement_at_triage                                         object
# ter_physical_distancing_in_waiting                                            object
# ter_separate_waiting_for_symptomatic                                          object
# chw_trained_precautions                                                       object
# chw_trained_community_service                                                 object
# chw_drugs                                                                     object
# chw_gloves                                                                    object
# chw_masks                                                                     object
# chw_iec_materials                                                             object
# iso_designated_isolation_for_suspected                                        object
# iso_distance_between_patients_in_waiting                                      object
# iso_distance_between_patient_beds                                             object
# iso_transfer_referral_protocol                                                object
# ipc_ppe_medical_masks                                                         object
# ipc_ppe_disp_surgical_masks                                                   object
# ipc_ppe_eye_protection                                                        object
# ipc_ppe_examination_gloves                                                    object
# ipc_ppe_surgical_gloves                                                       object
# ipc_ppe_long_cuffed_gloves                                                    object
# ipc_ppe_heavy_duty_gloves                                                     object
# ipc_ppe_long_sleeved_gown                                                     object
# ipc_ppe_waterproof_aprons                                                     object
# ipc_ppe_plan_staff_trained_on_ppe                                             object
# ipc_ppe_plan_ppe_poster_displayed                                             object
# ipc_ppe_plan_fit_test_kit                                                     object
# ipc_ppe_plan_contingency_for_shortages                                        object
# ipc_wcd_colour_coded_bins                                                     object
# ipc_wcd_clinical_waste_bags                                                   object
# ipc_wcd_laundry_receptacles_at_patient_rooms                                  object
# ipc_wcd_incinerator                                                           object
# ipc_wash_clean_running_water                                                  object
# ipc_wash_hand_soap                                                            object
# ipc_wash_liquid_soap                                                          object
# ipc_wash_disp_hand_towels                                                     object
# ipc_wash_alcohol_based_hand_gel                                               object
# ipc_ds_protocol_facility_disinfection                                         object
# ipc_ds_protocol_equipment_sterilisation                                       object
# ipc_ds_environmental_disinfectant                                             object
# ipc_ds_cleaning_schedule_in_toilets                                           object
# ipc_ds_protocol_corpse_handling                                               object
# log_referral_plan                                                             object
# log_cellphone_landline_swradio                                                object
# log_tracer_drugs                                                              object
# log_albendazole                                                               object
# log_amoxicillin                                                               object
# log_ampicillin                                                                object
# log_chlorhexidine_5                                                           object
# log_chlorhexidine_7                                                           object
# log_gentamicin                                                                object
# log_folic                                                                     object
# log_ferrous_and_folic                                                         object
# log_compound_sodium                                                           object
# log_co_trimoxazole_400                                                        object
# log_co_trimoxazole_200                                                        object
# log_metronidazole_250                                                         object
# log_metronidazole_200                                                         object
# log_methyldopa                                                                object
# log_magnesium_sulphate                                                        object
# log_lidocaine                                                                 object
# log_ibuprofen                                                                 object
# log_surgical_spirit                                                           object
# log_sodium_chloride                                                           object
# log_povidone                                                                  object
# log_paracetamol_500                                                           object
# log_paracetamol_250                                                           object
# log_ors                                                                       object
# log_gauze                                                                     object
# log_cotton_wool                                                               object
# log_cannula_iv_20                                                             object
# log_cannula_iv_24                                                             object
# log_zinc_sulphate                                                             object
# log_water                                                                     object
# log_needle_23                                                                 object
# log_needle_21                                                                 object
# log_glove_giving                                                              object
# log_glove_surgical                                                            object
# log_glove_gyn                                                                 object
# log_glove_exam                                                                object
# log_tape                                                                      object
# log_syringe                                                                   object
# log_oxytocin                                                                  object
# log_diazepam                                                                  object
# log_misoprostol                                                               object
# log_glucose                                                                   object
# consultations.head_count.monthly_average_head_counts                          object
# consultations.general_outpatient.monthly_average_general_outpatient           object
# consultations.deliveries.monthly_average_deliveries                           object
# consultations.pent_vaccines.monthly_average_pent_vaccines                     object
# score_human_resources                                                         object
# score_max_human_resources                                                     object
# score_information_education_communication                                     object
# score_max_information_education_communication                                 object
# score_surveillance                                                            object
# score_max_surveillance                                                        object
# score_triage_and_early_recognition                                            object
# score_max_triage_and_early_recognition                                        object
# score_chw                                                                     object
# score_max_chw                                                                 object
# score_isolation                                                               object
# score_max_isolation                                                           object
# score_infection_prevention_and_control_ppe                                    object
# score_max_infection_prevention_and_control_ppe                                object
# score_infection_prevention_and_control_ppe_plan                               object
# score_max_infection_prevention_and_control_ppe_plan                           object
# score_infection_prevention_and_control_waste_collection_and_disposal          object
# score_max_infection_prevention_and_control_waste_collection_and_disposal      object
# score_infection_prevention_and_control_water_sanitation_and_hygiene           object
# score_max_infection_prevention_and_control_water_sanitation_and_hygiene       object
# score_infection_prevention_and_control_disinfection_and_sterilization         object
# score_max_infection_prevention_and_control_disinfection_and_sterilization     object
# score_infection_prevention_and_control                                        object
# score_max_infection_prevention_and_control                                    object
# question1.score_logistics_patient_and_sample_transfer                         object
# question1.score_max_logistics_patient_and_sample_transfer                     object
# score_total                                                                  float64
# score_max_total                                                              float64
# dtype: object

# %% [markdown]
# There are lots of 'object' data types. Let's make the dataframe easier to use for modelling by assigning the correct data types. There are a lot of columns, so I assign data types in a bit of a hacky way below to save time. I consider the part of the column name after the last full stop. If it contains a particular keyword, I give it a particular data type. I use 16 bits for the integers because it's very unlikely that any facility will have more than around 32000 of any of the quantities in this database.

# %%
type_dict = {} # make a dictionary specifying data types for columns 
for col in df.columns:
    name_parts = col.split('.')
    
    if len(re.findall('number_', name_parts[-1]))!=0:
        type_dict[col] = 'Int16'
    elif name_parts[-1][:6]=='month_':
        type_dict[col] = 'Int16'
    elif name_parts[-1][:3]=='hr_':
        type_dict[col] = 'string'
    elif name_parts[-1][:4]=='iec_':
        type_dict[col] = 'string'
    elif name_parts[-1][:5]=='surv_':
        type_dict[col] = 'string'
    elif name_parts[-1][:4]=='ter_':
        type_dict[col] = 'string'
    elif name_parts[-1][:4]=='chw_':
        type_dict[col] = 'string'
    elif name_parts[-1][:4]=='iso_':
        type_dict[col] = 'string'
    elif name_parts[-1][:4]=='ipc_':
        type_dict[col] = 'string'
    elif name_parts[-1][:4]=='log_':
        type_dict[col] = 'string'
    elif name_parts[-1][:15]=='monthly_average':
        type_dict[col] = 'float64'
    elif name_parts[-1][:6]=='score_':
        type_dict[col] = 'float64'
type_dict_2 = {'facility_name': 'string', 'facility_gps_lat': 'float64', 'facility_gps_lon':'float64', 'region_province': 'string', 'district': 'string', 'chiefdom': 'string', 'facility_location': 'string', 'facility_type': 'string', 'facility_type_other': 'string', 'managing_authority': 'string', 'managing_authority_other': 'string', 'setting': 'string', 'outpatient_only': 'boolean' }
type_dict = type_dict | type_dict_2 # join two dictionaries

df=df.astype(type_dict)

# %% [markdown]
# We can check that the data types are now correct:

# %%
df.dtypes
# Out:
# facility_name                                                                 string
# facility_gps_lat                                                             float64
# facility_gps_lon                                                             float64
# region_province                                                               string
# district                                                                      string
# chiefdom                                                                      string
# facility_location                                                             string
# facility_type                                                                 string
# facility_type_other                                                           string
# managing_authority                                                            string
# managing_authority_other                                                      string
# setting                                                                       string
# outpatient_only                                                              boolean
# capacity.number_consultation_rooms                                             Int16
# capacity.number_inpatient_beds                                                 Int16
# capacity.number_maternity_beds                                                 Int16
# cho_number_in_post                                                             Int16
# cho_number_present_at_visit                                                    Int16
# cht_number_in_post                                                             Int16
# cht_number_present_at_visit                                                    Int16
# cha_number_in_post                                                             Int16
# cha_number_present_at_visit                                                    Int16
# cm_number_in_post                                                              Int16
# cm_number_present_at_visit                                                     Int16
# sechn_number_in_post                                                           Int16
# sechn_number_present_at_visit                                                  Int16
# lab_tech_number_in_post                                                        Int16
# lab_tech_number_present_at_visit                                               Int16
# mch_aides_number_in_post                                                       Int16
# mch_aides_number_present_at_visit                                              Int16
# cleaner_porter_number_in_post                                                  Int16
# cleaner_porter_number_present_at_visit                                         Int16
# other_number_in_post                                                           Int16
# other_number_present_at_visit                                                  Int16
# other_staff_cadre                                                             object
# sections_to_review                                                            object
# consultations.head_count.month_1                                               Int16
# consultations.head_count.month_2                                               Int16
# consultations.head_count.month_3                                               Int16
# consultations.head_count.month_4                                               Int16
# consultations.general_outpatient.month_1                                       Int16
# consultations.general_outpatient.month_2                                       Int16
# consultations.general_outpatient.month_3                                       Int16
# consultations.general_outpatient.month_4                                       Int16
# consultations.deliveries.month_1                                               Int16
# consultations.deliveries.month_2                                               Int16
# consultations.deliveries.month_3                                               Int16
# consultations.deliveries.month_4                                               Int16
# consultations.pent_vaccines.month_1                                            Int16
# consultations.pent_vaccines.month_2                                            Int16
# consultations.pent_vaccines.month_3                                            Int16
# consultations.pent_vaccines.month_4                                            Int16
# hr_focal_point                                                                string
# hr_staff_received_info                                                        string
# hr_healthcare_provider_training                                               string
# hr_healthcare_provider_revised_training                                       string
# hr_daily_staff_list                                                           string
# iec_handwashing_procedure                                                     string
# iec_physical_distancing                                                       string
# iec_covering_nose_mouth                                                       string
# iec_early_symptom_recognition                                                 string
# iec_when_facility_vs_home                                                     string
# iec_rational_ppe_use                                                          string
# iec_helpline_number                                                           string
# surv_procedure_for_notification                                               string
# surv_official_case_definition                                                 string
# surv_hotline_number                                                           string
# surv_timely_data_reported_to_district                                         string
# ter_screening_area_set_up                                                     string
# ter_symptom_screening_questionnaires                                          string
# ter_temperature_measurement_at_triage                                         string
# ter_physical_distancing_in_waiting                                            string
# ter_separate_waiting_for_symptomatic                                          string
# chw_trained_precautions                                                       string
# chw_trained_community_service                                                 string
# chw_drugs                                                                     string
# chw_gloves                                                                    string
# chw_masks                                                                     string
# chw_iec_materials                                                             string
# iso_designated_isolation_for_suspected                                        string
# iso_distance_between_patients_in_waiting                                      string
# iso_distance_between_patient_beds                                             string
# iso_transfer_referral_protocol                                                string
# ipc_ppe_medical_masks                                                         string
# ipc_ppe_disp_surgical_masks                                                   string
# ipc_ppe_eye_protection                                                        string
# ipc_ppe_examination_gloves                                                    string
# ipc_ppe_surgical_gloves                                                       string
# ipc_ppe_long_cuffed_gloves                                                    string
# ipc_ppe_heavy_duty_gloves                                                     string
# ipc_ppe_long_sleeved_gown                                                     string
# ipc_ppe_waterproof_aprons                                                     string
# ipc_ppe_plan_staff_trained_on_ppe                                             string
# ipc_ppe_plan_ppe_poster_displayed                                             string
# ipc_ppe_plan_fit_test_kit                                                     string
# ipc_ppe_plan_contingency_for_shortages                                        string
# ipc_wcd_colour_coded_bins                                                     string
# ipc_wcd_clinical_waste_bags                                                   string
# ipc_wcd_laundry_receptacles_at_patient_rooms                                  string
# ipc_wcd_incinerator                                                           string
# ipc_wash_clean_running_water                                                  string
# ipc_wash_hand_soap                                                            string
# ipc_wash_liquid_soap                                                          string
# ipc_wash_disp_hand_towels                                                     string
# ipc_wash_alcohol_based_hand_gel                                               string
# ipc_ds_protocol_facility_disinfection                                         string
# ipc_ds_protocol_equipment_sterilisation                                       string
# ipc_ds_environmental_disinfectant                                             string
# ipc_ds_cleaning_schedule_in_toilets                                           string
# ipc_ds_protocol_corpse_handling                                               string
# log_referral_plan                                                             string
# log_cellphone_landline_swradio                                                string
# log_tracer_drugs                                                              string
# log_albendazole                                                               string
# log_amoxicillin                                                               string
# log_ampicillin                                                                string
# log_chlorhexidine_5                                                           string
# log_chlorhexidine_7                                                           string
# log_gentamicin                                                                string
# log_folic                                                                     string
# log_ferrous_and_folic                                                         string
# log_compound_sodium                                                           string
# log_co_trimoxazole_400                                                        string
# log_co_trimoxazole_200                                                        string
# log_metronidazole_250                                                         string
# log_metronidazole_200                                                         string
# log_methyldopa                                                                string
# log_magnesium_sulphate                                                        string
# log_lidocaine                                                                 string
# log_ibuprofen                                                                 string
# log_surgical_spirit                                                           string
# log_sodium_chloride                                                           string
# log_povidone                                                                  string
# log_paracetamol_500                                                           string
# log_paracetamol_250                                                           string
# log_ors                                                                       string
# log_gauze                                                                     string
# log_cotton_wool                                                               string
# log_cannula_iv_20                                                             string
# log_cannula_iv_24                                                             string
# log_zinc_sulphate                                                             string
# log_water                                                                     string
# log_needle_23                                                                 string
# log_needle_21                                                                 string
# log_glove_giving                                                              string
# log_glove_surgical                                                            string
# log_glove_gyn                                                                 string
# log_glove_exam                                                                string
# log_tape                                                                      string
# log_syringe                                                                   string
# log_oxytocin                                                                  string
# log_diazepam                                                                  string
# log_misoprostol                                                               string
# log_glucose                                                                   string
# consultations.head_count.monthly_average_head_counts                         float64
# consultations.general_outpatient.monthly_average_general_outpatient          float64
# consultations.deliveries.monthly_average_deliveries                          float64
# consultations.pent_vaccines.monthly_average_pent_vaccines                    float64
# score_human_resources                                                        float64
# score_max_human_resources                                                    float64
# score_information_education_communication                                    float64
# score_max_information_education_communication                                float64
# score_surveillance                                                           float64
# score_max_surveillance                                                       float64
# score_triage_and_early_recognition                                           float64
# score_max_triage_and_early_recognition                                       float64
# score_chw                                                                    float64
# score_max_chw                                                                float64
# score_isolation                                                              float64
# score_max_isolation                                                          float64
# score_infection_prevention_and_control_ppe                                   float64
# score_max_infection_prevention_and_control_ppe                               float64
# score_infection_prevention_and_control_ppe_plan                              float64
# score_max_infection_prevention_and_control_ppe_plan                          float64
# score_infection_prevention_and_control_waste_collection_and_disposal         float64
# score_max_infection_prevention_and_control_waste_collection_and_disposal     float64
# score_infection_prevention_and_control_water_sanitation_and_hygiene          float64
# score_max_infection_prevention_and_control_water_sanitation_and_hygiene      float64
# score_infection_prevention_and_control_disinfection_and_sterilization        float64
# score_max_infection_prevention_and_control_disinfection_and_sterilization    float64
# score_infection_prevention_and_control                                       float64
# score_max_infection_prevention_and_control                                   float64
# question1.score_logistics_patient_and_sample_transfer                        float64
# question1.score_max_logistics_patient_and_sample_transfer                    float64
# score_total                                                                  float64
# score_max_total                                                              float64
# dtype: object

# %% [markdown]
# ## Specifying case

# %% [markdown]
# Python and many other languages are case sensitive, so a word like 'Python' is treated differently from 'python'. We can better detect duplicates if we make the case consistent throughout.

# %%
# get the names of all the string columns
str_cols = [i for i in df.columns if df.dtypes[i]=='string']

# make the string columns all lowercase
df[str_cols] = df[str_cols].apply(lambda x: x.str.lower(),axis=1)

# make location names all uppercase
df['facility_name'] = df['facility_name'].str.upper()
df['region_province'] = df['region_province'].str.upper()
df['district'] = df['district'].str.upper()
df['chiefdom'] = df['chiefdom'].str.upper()
df['facility_location'] = df['facility_location'].str.upper()

# %% [markdown]
# ## Dealing with duplicates

# %% [markdown]
# Now it's time to investigate duplicate data.
#
# Let's look for duplicate facility names:

# %%
df_dup_1 = df[df.duplicated(['facility_name'],keep=False)].sort_values('facility_name')
df_dup_1
# Out:
#         facility_name  facility_gps_lat  facility_gps_lon region_province  \
# number
# 41          AMBER CHP        -63.524311          4.306230   NORTH-WESTERN
# 44          AMBER CHP        -51.206867         -4.695275        SOUTHERN
# 25      JOANNA CLINIC         15.754015       -153.871776        SOUTHERN
# 47      JOANNA CLINIC         60.190934        162.787117        SOUTHERN
#
#        district       chiefdom facility_location            facility_type  \
# number
# 41       KARENE  MASSACHUSETTS   PORT CAROLBURGH                 mch_post
# 44      MOYAMBA        ALABAMA    NEW WALTERPORT  community_health_centre
# 25           BO    MISSISSIPPI      AMBERCHESTER                 mch_post
# 47           BO    MISSISSIPPI      AMBERCHESTER                 mch_post
#
#        facility_type_other managing_authority managing_authority_other  \
# number
# 41                    <NA>  government_public                     <NA>
# 44                    <NA>  government_public                     <NA>
# 25                    <NA>  government_public                     <NA>
# 47                    <NA>  government_public                     <NA>
#
#            setting  outpatient_only  capacity.number_consultation_rooms  \
# number
# 41      peri_urban            False                                   1
# 44            slum             True                                   2
# 25           rural             True                                   1
# 47      peri_urban             True                                   1
#
#         capacity.number_inpatient_beds  capacity.number_maternity_beds  \
# number
# 41                                   2                               1
# 44                                   5                               1
# 25                                   2                               1
# 47                                   2                               1
#
#         cho_number_in_post  cho_number_present_at_visit  cht_number_in_post  \
# number
# 41                       0                            0                   0
# 44                       2                            2                   0
# 25                       0                            0                   0
# 47                       0                            0                   0
#
#         cht_number_present_at_visit  cha_number_in_post  \
# number
# 41                                0                   0
# 44                                0                   0
# 25                                0                   0
# 47                                0                   0
#
#         cha_number_present_at_visit  cm_number_in_post  \
# number
# 41                                0                  0
# 44                                0                  0
# 25                                0                  0
# 47                                0                  0
#
#         cm_number_present_at_visit  sechn_number_in_post  \
# number
# 41                               0                     1
# 44                               0                     0
# 25                               0                     0
# 47                               0                     0
#
#         sechn_number_present_at_visit  lab_tech_number_in_post  \
# number
# 41                                  1                        0
# 44                                  0                        0
# 25                                  0                        0
# 47                                  0                        0
#
#         lab_tech_number_present_at_visit  mch_aides_number_in_post  \
# number
# 41                                     0                         1
# 44                                     0                         3
# 25                                     0                         3
# 47                                     0                         3
#
#         mch_aides_number_present_at_visit  cleaner_porter_number_in_post  \
# number
# 41                                      1                              0
# 44                                      3                              1
# 25                                      2                              1
# 47                                      2                              1
#
#         cleaner_porter_number_present_at_visit  other_number_in_post  \
# number
# 41                                           0                     0
# 44                                           1                     1
# 25                                           1                     4
# 47                                           1                     4
#
#         other_number_present_at_visit  \
# number
# 41                                  0
# 44                                  1
# 25                                  0
# 47                                  0
#
#                                         other_staff_cadre  \
# number
# 41                                                    NaN
# 44      1 security, 2 TBA,  Laboratory Assistant, 1 vo...
# 25                                                  TBA's
# 47                                                  TBA's
#
#                                        sections_to_review  \
# number
# 41      consultations hr information_education_communi...
# 44      consultations hr information_education_communi...
# 25      consultations hr information_education_communi...
# 47      consultations hr information_education_communi...
#
#         consultations.head_count.month_1  consultations.head_count.month_2  \
# number
# 41                                   481                               355
# 44                                   492                               537
# 25                                   388                               153
# 47                                   388                               153
#
#         consultations.head_count.month_3  consultations.head_count.month_4  \
# number
# 41                                   264                               223
# 44                                   486                               524
# 25                                   180                               183
# 47                                   180                               183
#
#         consultations.general_outpatient.month_1  \
# number
# 41                                            57
# 44                                           396
# 25                                           133
# 47                                           133
#
#         consultations.general_outpatient.month_2  \
# number
# 41                                            50
# 44                                           392
# 25                                            30
# 47                                            30
#
#         consultations.general_outpatient.month_3  \
# number
# 41                                            40
# 44                                           291
# 25                                            21
# 47                                            21
#
#         consultations.general_outpatient.month_4  \
# number
# 41                                            28
# 44                                           254
# 25                                            55
# 47                                            55
#
#         consultations.deliveries.month_1  consultations.deliveries.month_2  \
# number
# 41                                    12                                11
# 44                                    11                                 7
# 25                                    18                                10
# 47                                    18                                10
#
#         consultations.deliveries.month_3  consultations.deliveries.month_4  \
# number
# 41                                     9                                 8
# 44                                    10                                11
# 25                                    14                                14
# 47                                    14                                14
#
#         consultations.pent_vaccines.month_1  \
# number
# 41                                        6
# 44                                       12
# 25                                       17
# 47                                       17
#
#         consultations.pent_vaccines.month_2  \
# number
# 41                                       12
# 44                                       13
# 25                                       18
# 47                                       18
#
#         consultations.pent_vaccines.month_3  \
# number
# 41                                       12
# 44                                       13
# 25                                       12
# 47                                       12
#
#         consultations.pent_vaccines.month_4 hr_focal_point  \
# number
# 41                                       12  not_completed
# 44                                       15      completed
# 25                                       19  not_completed
# 47                                       19  not_completed
#
#        hr_staff_received_info hr_healthcare_provider_training  \
# number
# 41                  completed                       completed
# 44                  completed                       completed
# 25        partially_completed                   not_completed
# 47        partially_completed                   not_completed
#
#        hr_healthcare_provider_revised_training hr_daily_staff_list  \
# number
# 41                                   completed           completed
# 44                                   completed           completed
# 25                               not_completed       not_completed
# 47                               not_completed       not_completed
#
#        iec_handwashing_procedure iec_physical_distancing  \
# number
# 41                     displayed               displayed
# 44                     displayed               displayed
# 25                 not_displayed           not_displayed
# 47                 not_displayed           not_displayed
#
#        iec_covering_nose_mouth iec_early_symptom_recognition  \
# number
# 41               not_displayed                     displayed
# 44                   displayed                     displayed
# 25               not_displayed                 not_displayed
# 47               not_displayed                 not_displayed
#
#        iec_when_facility_vs_home iec_rational_ppe_use iec_helpline_number  \
# number
# 41                     displayed            displayed       not_displayed
# 44                     displayed            displayed           displayed
# 25                 not_displayed            displayed       not_displayed
# 47                 not_displayed            displayed       not_displayed
#
#        surv_procedure_for_notification surv_official_case_definition  \
# number
# 41                        not_in_place             fully_operational
# 44                   fully_operational             fully_operational
# 25                        not_in_place                  not_in_place
# 47                        not_in_place                  not_in_place
#
#           surv_hotline_number surv_timely_data_reported_to_district  \
# number
# 41          fully_operational                     fully_operational
# 44      partially_operational                     fully_operational
# 25      partially_operational                          not_in_place
# 47          fully_operational                     fully_operational
#
#        ter_screening_area_set_up ter_symptom_screening_questionnaires  \
# number
# 41                  not_in_place                         not_in_place
# 44             fully_operational                    fully_operational
# 25                  not_in_place                         not_in_place
# 47         partially_operational                         not_in_place
#
#        ter_temperature_measurement_at_triage  \
# number
# 41                              not_in_place
# 44                         fully_operational
# 25                              not_in_place
# 47                              not_in_place
#
#        ter_physical_distancing_in_waiting  \
# number
# 41                  partially_operational
# 44                      fully_operational
# 25                      fully_operational
# 47                      fully_operational
#
#        ter_separate_waiting_for_symptomatic chw_trained_precautions  \
# number
# 41                             not_in_place                adequate
# 44                        fully_operational                 partial
# 25                             not_in_place            not_in_place
# 47                             not_in_place            not_in_place
#
#        chw_trained_community_service     chw_drugs    chw_gloves  \
# number
# 41                          adequate      adequate      adequate
# 44                           partial       partial       partial
# 25                      not_in_place       partial  not_in_place
# 47                      not_in_place  not_in_place  not_in_place
#
#            chw_masks chw_iec_materials iso_designated_isolation_for_suspected  \
# number
# 41      not_in_place      not_in_place                  partially_operational
# 44           partial          adequate                      fully_operational
# 25              <NA>      not_in_place                           not_in_place
# 47      not_in_place      not_in_place                           not_in_place
#
#        iso_distance_between_patients_in_waiting  \
# number
# 41                                 not_in_place
# 44                            fully_operational
# 25                            fully_operational
# 47                            fully_operational
#
#        iso_distance_between_patient_beds iso_transfer_referral_protocol  \
# number
# 41                          not_in_place              fully_operational
# 44                     fully_operational              fully_operational
# 25                     fully_operational              fully_operational
# 47                     fully_operational              fully_operational
#
#        ipc_ppe_medical_masks ipc_ppe_disp_surgical_masks  \
# number
# 41       sufficient_supplies         sufficient_supplies
# 44          risk_of_shortage         sufficient_supplies
# 25          risk_of_shortage               not_available
# 47          risk_of_shortage               not_available
#
#        ipc_ppe_eye_protection ipc_ppe_examination_gloves  \
# number
# 41        sufficient_supplies        sufficient_supplies
# 44        sufficient_supplies        sufficient_supplies
# 25              not_available           risk_of_shortage
# 47              not_available           risk_of_shortage
#
#        ipc_ppe_surgical_gloves ipc_ppe_long_cuffed_gloves  \
# number
# 41         sufficient_supplies              not_available
# 44         sufficient_supplies        sufficient_supplies
# 25               not_available              not_available
# 47               not_available              not_available
#
#        ipc_ppe_heavy_duty_gloves ipc_ppe_long_sleeved_gown  \
# number
# 41           sufficient_supplies       sufficient_supplies
# 44           sufficient_supplies       sufficient_supplies
# 25                 not_available             not_available
# 47                 not_available             not_available
#
#        ipc_ppe_waterproof_aprons ipc_ppe_plan_staff_trained_on_ppe  \
# number
# 41           sufficient_supplies                partially_achieved
# 44           sufficient_supplies          available_fully_achieved
# 25                 not_available                     not_available
# 47                 not_available                     not_available
#
#        ipc_ppe_plan_ppe_poster_displayed ipc_ppe_plan_fit_test_kit  \
# number
# 41              available_fully_achieved             not_available
# 44              available_fully_achieved  available_fully_achieved
# 25                         not_available             not_available
# 47                         not_available             not_available
#
#        ipc_ppe_plan_contingency_for_shortages ipc_wcd_colour_coded_bins  \
# number
# 41                              not_available       sufficient_supplies
# 44                   available_fully_achieved       sufficient_supplies
# 25                         partially_achieved          risk_of_shortage
# 47                         partially_achieved          risk_of_shortage
#
#        ipc_wcd_clinical_waste_bags  \
# number
# 41             sufficient_supplies
# 44             sufficient_supplies
# 25                risk_of_shortage
# 47                risk_of_shortage
#
#        ipc_wcd_laundry_receptacles_at_patient_rooms  ipc_wcd_incinerator  \
# number
# 41                                    not_available  sufficient_supplies
# 44                              sufficient_supplies  sufficient_supplies
# 25                                    not_available        not_available
# 47                                    not_available        not_available
#
#        ipc_wash_clean_running_water ipc_wash_hand_soap ipc_wash_liquid_soap  \
# number
# 41              sufficient_supplies      not_available        not_available
# 44              sufficient_supplies   risk_of_shortage        not_available
# 25                 risk_of_shortage      not_available        not_available
# 47                 risk_of_shortage      not_available        not_available
#
#        ipc_wash_disp_hand_towels ipc_wash_alcohol_based_hand_gel  \
# number
# 41                 not_available                   not_available
# 44                 not_available             sufficient_supplies
# 25                 not_available                   not_available
# 47                 not_available                   not_available
#
#        ipc_ds_protocol_facility_disinfection  \
# number
# 41                             not_available
# 44                       sufficient_supplies
# 25                          risk_of_shortage
# 47                          risk_of_shortage
#
#        ipc_ds_protocol_equipment_sterilisation  \
# number
# 41                               not_available
# 44                         sufficient_supplies
# 25                               not_available
# 47                               not_available
#
#        ipc_ds_environmental_disinfectant ipc_ds_cleaning_schedule_in_toilets  \
# number
# 41                         not_available                       not_available
# 44                   sufficient_supplies                 sufficient_supplies
# 25                         not_available                    risk_of_shortage
# 47                         not_available                    risk_of_shortage
#
#        ipc_ds_protocol_corpse_handling log_referral_plan  \
# number
# 41                       not_available         available
# 44                 sufficient_supplies         available
# 25                       not_available         available
# 47                       not_available         available
#
#        log_cellphone_landline_swradio     log_tracer_drugs log_albendazole  \
# number
# 41                      not_available            available   not_available
# 44                partially_available            available       available
# 25                      not_available  partially_available       available
# 47                      not_available        not_available       available
#
#             log_amoxicillin       log_ampicillin  log_chlorhexidine_5  \
# number
# 41                available        not_available            available
# 44                available        not_available            available
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#         log_chlorhexidine_7       log_gentamicin      log_folic  \
# number
# 41            not_available            available      available
# 44      partially_available            available           <NA>
# 25            not_available  partially_available  not_available
# 47            not_available  partially_available  not_available
#
#        log_ferrous_and_folic log_compound_sodium log_co_trimoxazole_400  \
# number
# 41             not_available                <NA>              available
# 44                 available           available              available
# 25             not_available       not_available          not_available
# 47             not_available       not_available          not_available
#
#        log_co_trimoxazole_200 log_metronidazole_250 log_metronidazole_200  \
# number
# 41              not_available             available         not_available
# 44                  available             available             available
# 25              not_available   partially_available         not_available
# 47              not_available   partially_available         not_available
#
#              log_methyldopa log_magnesium_sulphate        log_lidocaine  \
# number
# 41                available              available            available
# 44                available              available            available
# 25      partially_available    partially_available  partially_available
# 47      partially_available    partially_available  partially_available
#
#         log_ibuprofen log_surgical_spirit  log_sodium_chloride   log_povidone  \
# number
# 41          available           available            available      available
# 44          available           available            available      available
# 25      not_available       not_available  partially_available  not_available
# 47      not_available       not_available  partially_available  not_available
#
#        log_paracetamol_500 log_paracetamol_250              log_ors  \
# number
# 41               available       not_available            available
# 44               available           available            available
# 25           not_available       not_available  partially_available
# 47           not_available       not_available  partially_available
#
#             log_gauze      log_cotton_wool log_cannula_iv_20  \
# number
# 41          available        not_available     not_available
# 44      not_available            available         available
# 25      not_available  partially_available     not_available
# 47      not_available  partially_available     not_available
#
#        log_cannula_iv_24    log_zinc_sulphate            log_water  \
# number
# 41         not_available            available            available
# 44             available            available            available
# 25         not_available  partially_available  partially_available
# 47         not_available  partially_available  partially_available
#
#               log_needle_23  log_needle_21     log_glove_giving  \
# number
# 41            not_available  not_available            available
# 44                available      available            available
# 25      partially_available  not_available  partially_available
# 47      partially_available  not_available  partially_available
#
#          log_glove_surgical  log_glove_gyn       log_glove_exam  \
# number
# 41                available      available            available
# 44                     <NA>      available            available
# 25      partially_available  not_available  partially_available
# 47            not_available  not_available  partially_available
#
#                    log_tape          log_syringe         log_oxytocin  \
# number
# 41            not_available            available            available
# 44                available            available            available
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_diazepam log_misoprostol    log_glucose  \
# number
# 41        available   not_available  not_available
# 44        available   not_available      available
# 25        available   not_available  not_available
# 47        available   not_available  not_available
#
#         consultations.head_count.monthly_average_head_counts  \
# number
# 41                                                 330.75
# 44                                                 509.75
# 25                                                 226.00
# 47                                                 226.00
#
#         consultations.general_outpatient.monthly_average_general_outpatient  \
# number
# 41                                                  43.75
# 44                                                 333.25
# 25                                                  59.75
# 47                                                  59.75
#
#         consultations.deliveries.monthly_average_deliveries  \
# number
# 41                                                  10.00
# 44                                                   9.75
# 25                                                  14.00
# 47                                                  14.00
#
#         consultations.pent_vaccines.monthly_average_pent_vaccines  \
# number
# 41                                                  10.50
# 44                                                  13.25
# 25                                                  16.50
# 47                                                  16.50
#
#         score_human_resources  score_max_human_resources  \
# number
# 41                        4.0                        5.0
# 44                        5.0                        5.0
# 25                        0.5                        5.0
# 47                        0.5                        5.0
#
#         score_information_education_communication  \
# number
# 41                                            5.0
# 44                                            7.0
# 25                                            1.0
# 47                                            1.0
#
#         score_max_information_education_communication  score_surveillance  \
# number
# 41                                                7.0                 3.0
# 44                                                7.0                 3.5
# 25                                                7.0                 0.5
# 47                                                7.0                 2.0
#
#         score_max_surveillance  score_triage_and_early_recognition  \
# number
# 41                         4.0                                 0.5
# 44                         4.0                                 5.0
# 25                         4.0                                 1.0
# 47                         4.0                                 1.5
#
#         score_max_triage_and_early_recognition  score_chw  score_max_chw  \
# number
# 41                                         5.0        3.0            6.0
# 44                                         5.0        3.0            6.0
# 25                                         5.0        0.5            6.0
# 47                                         5.0        0.0            6.0
#
#         score_isolation  score_max_isolation  \
# number
# 41                  1.5                  4.0
# 44                  4.0                  4.0
# 25                  3.0                  4.0
# 47                  3.0                  4.0
#
#         score_infection_prevention_and_control_ppe  \
# number
# 41                                             8.0
# 44                                             8.5
# 25                                             1.0
# 47                                             1.0
#
#         score_max_infection_prevention_and_control_ppe  \
# number
# 41                                                 9.0
# 44                                                 9.0
# 25                                                 9.0
# 47                                                 9.0
#
#         score_infection_prevention_and_control_ppe_plan  \
# number
# 41                                                  1.5
# 44                                                  4.0
# 25                                                  0.5
# 47                                                  0.5
#
#         score_max_infection_prevention_and_control_ppe_plan  \
# number
# 41                                                    4.0
# 44                                                    4.0
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 41                                                    3.0
# 44                                                    4.0
# 25                                                    1.0
# 47                                                    1.0
#
#         score_max_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 41                                                    4.0
# 44                                                    4.0
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 41                                                    1.0
# 44                                                    2.5
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 41                                                    5.0
# 44                                                    5.0
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 41                                                    0.0
# 44                                                    4.0
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 41                                                    5.0
# 44                                                    5.0
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control  \
# number
# 41                                        13.5
# 44                                        23.0
# 25                                         3.5
# 47                                         3.5
#
#         score_max_infection_prevention_and_control  \
# number
# 41                                            27.0
# 44                                            27.0
# 25                                            27.0
# 47                                            27.0
#
#         question1.score_logistics_patient_and_sample_transfer  \
# number
# 41                                                   26.0
# 44                                                   36.0
# 25                                                   12.0
# 47                                                   11.0
#
#         question1.score_max_logistics_patient_and_sample_transfer  \
# number
# 41                                                   44.0
# 44                                                   44.0
# 25                                                   44.0
# 47                                                   44.0
#
#         score_total  score_max_total
# number
# 41             56.5            102.0
# 44             86.5            102.0
# 25             22.0            102.0
# 47             22.5            102.0

# %% [markdown]
# Let's see how many elements are in this dataframe:

# %%
len(df_dup_1)
# Out:
# 4

# %% [markdown]
# It is possible that some duplicates are 'hiding' because the names are spelled slightly differently. Let's see if we can catch any like that by printing out all the facilities that have location matches with other facilities.

# %%
df[df.duplicated(['facility_location'],keep=False)].sort_values('facility_location')
# Out:
#                     facility_name  facility_gps_lat  facility_gps_lon  \
# number
# 25                  JOANNA CLINIC         15.754015       -153.871776
# 47                  JOANNA CLINIC         60.190934        162.787117
# 18                     ROBERT CHP        -44.270199        153.380144
# 20       STEVEN TERTIARY HOSPITAL         -9.283850         51.933410
# 23               ZOE HOSPITAL/CHC        -26.352292         97.523226
# 42       ROBERT REGIONAL HOSPITAL        -15.224350         87.259650
# 16                ROBERT HOSPITAL         43.308952        134.454731
# 33      REBEKAH TERTIARY HOSPITAL        -64.696061       -155.675806
# 34            ANDREW HOSPITAL/CHC         44.582128       -149.870484
#
#        region_province            district      chiefdom facility_location  \
# number
# 25            SOUTHERN                  BO   MISSISSIPPI      AMBERCHESTER
# 47            SOUTHERN                  BO   MISSISSIPPI      AMBERCHESTER
# 18        WESTERN AREA  WESTERN AREA URBAN      KENTUCKY      COLLEENBURGH
# 20             WESTERN  WESTERN AREA URBAN      ILLINOIS      COLLEENBURGH
# 23             WESTERN  WESTERN AREA URBAN  RHODE ISLAND      COLLEENBURGH
# 42             WESTERN  WESTERN AREA URBAN  RHODE ISLAND      COLLEENBURGH
# 16       NORTH-WESTERN           PORT LOKO      KENTUCKY    VALERIEBOROUGH
# 33       NORTH-WESTERN           PORT LOKO       MONTANA    VALERIEBOROUGH
# 34       NORTH-WESTERN           PORT LOKO        OREGON    VALERIEBOROUGH
#
#                   facility_type facility_type_other managing_authority  \
# number
# 25                     mch_post                <NA>  government_public
# 47                     mch_post                <NA>  government_public
# 18      community_health_centre                <NA>  government_public
# 20      community_health_centre                <NA>  government_public
# 23                     mch_post                <NA>  government_public
# 42      community_health_centre                <NA>  government_public
# 16      community_health_centre                <NA>  government_public
# 33        community_health_post                <NA>  government_public
# 34        community_health_post                <NA>  government_public
#
#        managing_authority_other     setting  outpatient_only  \
# number
# 25                         <NA>       rural             True
# 47                         <NA>  peri_urban             True
# 18                         <NA>       urban             True
# 20                         <NA>       urban             True
# 23                         <NA>       urban             True
# 42                         <NA>       urban             True
# 16                         <NA>       urban             True
# 33                         <NA>  peri_urban             True
# 34                         <NA>  peri_urban             True
#
#         capacity.number_consultation_rooms  capacity.number_inpatient_beds  \
# number
# 25                                       1                               2
# 47                                       1                               2
# 18                                       4                               5
# 20                                       3                               2
# 23                                       2                               3
# 42                                       4                               6
# 16                                       3                               4
# 33                                       2                               0
# 34                                       1                               0
#
#         capacity.number_maternity_beds  cho_number_in_post  \
# number
# 25                                   1                   0
# 47                                   1                   0
# 18                                   4                   1
# 20                                   1                   2
# 23                                   2                   0
# 42                                   2                   2
# 16                                   3                   1
# 33                                   3                   0
# 34                                   2                   0
#
#         cho_number_present_at_visit  cht_number_in_post  \
# number
# 25                                0                   0
# 47                                0                   0
# 18                                0                   0
# 20                                0                   0
# 23                                0                   0
# 42                                1                   0
# 16                                1                   0
# 33                                0                   0
# 34                                0                   0
#
#         cht_number_present_at_visit  cha_number_in_post  \
# number
# 25                                0                   0
# 47                                0                   0
# 18                                0                   0
# 20                                0                   0
# 23                                0                   0
# 42                                0                   2
# 16                                0                   0
# 33                                0                   0
# 34                                0                   0
#
#         cha_number_present_at_visit  cm_number_in_post  \
# number
# 25                                0                  0
# 47                                0                  0
# 18                                0                  2
# 20                                0                  2
# 23                                0                  0
# 42                                0                  3
# 16                                0                  1
# 33                                0                  0
# 34                                0                  0
#
#         cm_number_present_at_visit  sechn_number_in_post  \
# number
# 25                               0                     0
# 47                               0                     0
# 18                               1                     7
# 20                               1                     3
# 23                               0                     2
# 42                               1                     8
# 16                               1                     0
# 33                               0                     3
# 34                               0                     2
#
#         sechn_number_present_at_visit  lab_tech_number_in_post  \
# number
# 25                                  0                        0
# 47                                  0                        0
# 18                                  3                        0
# 20                                  0                        4
# 23                                  1                        0
# 42                                  1                        3
# 16                                  0                        0
# 33                                  2                        0
# 34                                  1                        0
#
#         lab_tech_number_present_at_visit  mch_aides_number_in_post  \
# number
# 25                                     0                         3
# 47                                     0                         3
# 18                                     0                         7
# 20                                     1                         7
# 23                                     0                         3
# 42                                     2                         4
# 16                                     0                         3
# 33                                     0                         3
# 34                                     0                         0
#
#         mch_aides_number_present_at_visit  cleaner_porter_number_in_post  \
# number
# 25                                      2                              1
# 47                                      2                              1
# 18                                      3                              0
# 20                                      1                              1
# 23                                      3                              0
# 42                                      0                              0
# 16                                      2                              0
# 33                                      3                              0
# 34                                      0                              1
#
#         cleaner_porter_number_present_at_visit  other_number_in_post  \
# number
# 25                                           1                     4
# 47                                           1                     4
# 18                                           0                     2
# 20                                           0                     1
# 23                                           0                     0
# 42                                           0                     0
# 16                                           0                     0
# 33                                           0                     0
# 34                                           1                     0
#
#         other_number_present_at_visit other_staff_cadre  \
# number
# 25                                  0             TBA's
# 47                                  0             TBA's
# 18                                  0      nursing aide
# 20                                  0      Nursing Aide
# 23                                  0               NaN
# 42                                  0               NaN
# 16                                  0               NaN
# 33                                  0               NaN
# 34                                  0               NaN
#
#                                        sections_to_review  \
# number
# 25      consultations hr information_education_communi...
# 47      consultations hr information_education_communi...
# 18      consultations hr information_education_communi...
# 20      hr information_education_communication surveil...
# 23      consultations hr information_education_communi...
# 42      consultations hr information_education_communi...
# 16                                          consultations
# 33      consultations hr information_education_communi...
# 34      consultations hr information_education_communi...
#
#         consultations.head_count.month_1  consultations.head_count.month_2  \
# number
# 25                                   388                               153
# 47                                   388                               153
# 18                                  1148                               931
# 20                                  <NA>                              <NA>
# 23                                   693                               649
# 42                                   880                              1050
# 16                                   301                               226
# 33                                   780                               805
# 34                                   288                               243
#
#         consultations.head_count.month_3  consultations.head_count.month_4  \
# number
# 25                                   180                               183
# 47                                   180                               183
# 18                                   997                               874
# 20                                  <NA>                              <NA>
# 23                                   733                               542
# 42                                   911                               652
# 16                                   352                               149
# 33                                   760                              1044
# 34                                   283                               141
#
#         consultations.general_outpatient.month_1  \
# number
# 25                                           133
# 47                                           133
# 18                                           567
# 20                                          <NA>
# 23                                           439
# 42                                           352
# 16                                           155
# 33                                           363
# 34                                           189
#
#         consultations.general_outpatient.month_2  \
# number
# 25                                            30
# 47                                            30
# 18                                           462
# 20                                          <NA>
# 23                                           522
# 42                                           544
# 16                                           120
# 33                                           448
# 34                                           145
#
#         consultations.general_outpatient.month_3  \
# number
# 25                                            21
# 47                                            21
# 18                                           504
# 20                                          <NA>
# 23                                           513
# 42                                           657
# 16                                           140
# 33                                           340
# 34                                           145
#
#         consultations.general_outpatient.month_4  \
# number
# 25                                            55
# 47                                            55
# 18                                           402
# 20                                          <NA>
# 23                                           344
# 42                                           250
# 16                                            97
# 33                                           403
# 34                                            90
#
#         consultations.deliveries.month_1  consultations.deliveries.month_2  \
# number
# 25                                    18                                10
# 47                                    18                                10
# 18                                    26                                32
# 20                                  <NA>                              <NA>
# 23                                    25                                18
# 42                                    40                                41
# 16                                    25                                26
# 33                                    40                                37
# 34                                    11                                 7
#
#         consultations.deliveries.month_3  consultations.deliveries.month_4  \
# number
# 25                                    14                                14
# 47                                    14                                14
# 18                                    28                                28
# 20                                  <NA>                              <NA>
# 23                                    20                                15
# 42                                    96                                28
# 16                                    20                                10
# 33                                    28                                29
# 34                                    16                                 2
#
#         consultations.pent_vaccines.month_1  \
# number
# 25                                       17
# 47                                       17
# 18                                       37
# 20                                     <NA>
# 23                                       34
# 42                                        0
# 16                                       23
# 33                                       34
# 34                                       12
#
#         consultations.pent_vaccines.month_2  \
# number
# 25                                       18
# 47                                       18
# 18                                       42
# 20                                     <NA>
# 23                                       32
# 42                                       70
# 16                                       17
# 33                                       39
# 34                                       11
#
#         consultations.pent_vaccines.month_3  \
# number
# 25                                       12
# 47                                       12
# 18                                       42
# 20                                     <NA>
# 23                                       20
# 42                                       52
# 16                                       15
# 33                                       35
# 34                                       26
#
#         consultations.pent_vaccines.month_4       hr_focal_point  \
# number
# 25                                       19        not_completed
# 47                                       19        not_completed
# 18                                       33        not_completed
# 20                                     <NA>        not_completed
# 23                                       32  partially_completed
# 42                                        0            completed
# 16                                       23                 <NA>
# 33                                       35        not_completed
# 34                                        0        not_completed
#
#        hr_staff_received_info hr_healthcare_provider_training  \
# number
# 25        partially_completed                   not_completed
# 47        partially_completed                   not_completed
# 18        partially_completed                   not_completed
# 20              not_completed                   not_completed
# 23        partially_completed             partially_completed
# 42        partially_completed             partially_completed
# 16                       <NA>                            <NA>
# 33                  completed                   not_completed
# 34                  completed             partially_completed
#
#        hr_healthcare_provider_revised_training hr_daily_staff_list  \
# number
# 25                               not_completed       not_completed
# 47                               not_completed       not_completed
# 18                         partially_completed       not_completed
# 20                               not_completed       not_completed
# 23                         partially_completed       not_completed
# 42                               not_completed       not_completed
# 16                                        <NA>                <NA>
# 33                               not_completed           completed
# 34                               not_completed           completed
#
#        iec_handwashing_procedure iec_physical_distancing  \
# number
# 25                 not_displayed           not_displayed
# 47                 not_displayed           not_displayed
# 18                     displayed           not_displayed
# 20                     displayed           not_displayed
# 23                     displayed           not_displayed
# 42                     displayed               displayed
# 16                          <NA>                    <NA>
# 33                 not_displayed           not_displayed
# 34                     displayed           not_displayed
#
#        iec_covering_nose_mouth iec_early_symptom_recognition  \
# number
# 25               not_displayed                 not_displayed
# 47               not_displayed                 not_displayed
# 18               not_displayed                 not_displayed
# 20               not_displayed                 not_displayed
# 23                   displayed                     displayed
# 42                   displayed                     displayed
# 16                        <NA>                          <NA>
# 33               not_displayed                     displayed
# 34               not_displayed                 not_displayed
#
#        iec_when_facility_vs_home iec_rational_ppe_use iec_helpline_number  \
# number
# 25                 not_displayed            displayed       not_displayed
# 47                 not_displayed            displayed       not_displayed
# 18                 not_displayed        not_displayed       not_displayed
# 20                 not_displayed        not_displayed       not_displayed
# 23                     displayed            displayed           displayed
# 42                     displayed        not_displayed           displayed
# 16                          <NA>                 <NA>                <NA>
# 33                 not_displayed            displayed           displayed
# 34                 not_displayed        not_displayed       not_displayed
#
#        surv_procedure_for_notification surv_official_case_definition  \
# number
# 25                        not_in_place                  not_in_place
# 47                        not_in_place                  not_in_place
# 18               partially_operational         partially_operational
# 20               partially_operational                  not_in_place
# 23               partially_operational         partially_operational
# 42                        not_in_place         partially_operational
# 16                                <NA>                          <NA>
# 33                   fully_operational                  not_in_place
# 34                   fully_operational                  not_in_place
#
#           surv_hotline_number surv_timely_data_reported_to_district  \
# number
# 25      partially_operational                          not_in_place
# 47          fully_operational                     fully_operational
# 18          fully_operational                     fully_operational
# 20               not_in_place                     fully_operational
# 23          fully_operational                     fully_operational
# 42          fully_operational                     fully_operational
# 16                       <NA>                                  <NA>
# 33          fully_operational                     fully_operational
# 34          fully_operational                     fully_operational
#
#        ter_screening_area_set_up ter_symptom_screening_questionnaires  \
# number
# 25                  not_in_place                         not_in_place
# 47         partially_operational                         not_in_place
# 18         partially_operational                partially_operational
# 20         partially_operational                         not_in_place
# 23                  not_in_place                         not_in_place
# 42         partially_operational                    fully_operational
# 16                          <NA>                                 <NA>
# 33             fully_operational                         not_in_place
# 34                  not_in_place                         not_in_place
#
#        ter_temperature_measurement_at_triage  \
# number
# 25                              not_in_place
# 47                              not_in_place
# 18                         fully_operational
# 20                              not_in_place
# 23                              not_in_place
# 42                         fully_operational
# 16                                      <NA>
# 33                     partially_operational
# 34                     partially_operational
#
#        ter_physical_distancing_in_waiting  \
# number
# 25                      fully_operational
# 47                      fully_operational
# 18                      fully_operational
# 20                           not_in_place
# 23                           not_in_place
# 42                      fully_operational
# 16                                   <NA>
# 33                      fully_operational
# 34                      fully_operational
#
#        ter_separate_waiting_for_symptomatic chw_trained_precautions  \
# number
# 25                             not_in_place            not_in_place
# 47                             not_in_place            not_in_place
# 18                    partially_operational                adequate
# 20                             not_in_place            not_in_place
# 23                             not_in_place                adequate
# 42                             not_in_place                adequate
# 16                                     <NA>                    <NA>
# 33                        fully_operational                 partial
# 34                             not_in_place                 partial
#
#        chw_trained_community_service     chw_drugs    chw_gloves  \
# number
# 25                      not_in_place       partial  not_in_place
# 47                      not_in_place  not_in_place  not_in_place
# 18                          adequate      adequate       partial
# 20                      not_in_place  not_in_place  not_in_place
# 23                          adequate  not_in_place  not_in_place
# 42                           partial      adequate       partial
# 16                              <NA>          <NA>          <NA>
# 33                           partial      adequate      adequate
# 34                           partial       partial  not_in_place
#
#            chw_masks chw_iec_materials iso_designated_isolation_for_suspected  \
# number
# 25              <NA>      not_in_place                           not_in_place
# 47      not_in_place      not_in_place                           not_in_place
# 18           partial      not_in_place                           not_in_place
# 20      not_in_place      not_in_place                  partially_operational
# 23           partial      not_in_place                           not_in_place
# 42           partial      not_in_place                           not_in_place
# 16              <NA>              <NA>                                   <NA>
# 33      not_in_place      not_in_place                  partially_operational
# 34      not_in_place      not_in_place                           not_in_place
#
#        iso_distance_between_patients_in_waiting  \
# number
# 25                            fully_operational
# 47                            fully_operational
# 18                        partially_operational
# 20                        partially_operational
# 23                                 not_in_place
# 42                                 not_in_place
# 16                                         <NA>
# 33                            fully_operational
# 34                            fully_operational
#
#        iso_distance_between_patient_beds iso_transfer_referral_protocol  \
# number
# 25                     fully_operational              fully_operational
# 47                     fully_operational              fully_operational
# 18                 partially_operational              fully_operational
# 20                 partially_operational          partially_operational
# 23                          not_in_place          partially_operational
# 42                          not_in_place                   not_in_place
# 16                                  <NA>                           <NA>
# 33                     fully_operational              fully_operational
# 34                          not_in_place              fully_operational
#
#        ipc_ppe_medical_masks ipc_ppe_disp_surgical_masks  \
# number
# 25          risk_of_shortage               not_available
# 47          risk_of_shortage               not_available
# 18          risk_of_shortage            risk_of_shortage
# 20             not_available                        <NA>
# 23             not_available            risk_of_shortage
# 42             not_available               not_available
# 16                      <NA>                        <NA>
# 33             not_available               not_available
# 34          risk_of_shortage            risk_of_shortage
#
#        ipc_ppe_eye_protection ipc_ppe_examination_gloves  \
# number
# 25              not_available           risk_of_shortage
# 47              not_available           risk_of_shortage
# 18              not_available           risk_of_shortage
# 20                       <NA>                       <NA>
# 23              not_available           risk_of_shortage
# 42           risk_of_shortage              not_available
# 16                       <NA>                       <NA>
# 33              not_available              not_available
# 34        sufficient_supplies        sufficient_supplies
#
#        ipc_ppe_surgical_gloves ipc_ppe_long_cuffed_gloves  \
# number
# 25               not_available              not_available
# 47               not_available              not_available
# 18               not_available              not_available
# 20                        <NA>                       <NA>
# 23               not_available              not_available
# 42               not_available              not_available
# 16                        <NA>                       <NA>
# 33               not_available              not_available
# 34         sufficient_supplies              not_available
#
#        ipc_ppe_heavy_duty_gloves ipc_ppe_long_sleeved_gown  \
# number
# 25                 not_available             not_available
# 47                 not_available             not_available
# 18                 not_available             not_available
# 20                          <NA>                      <NA>
# 23                 not_available          risk_of_shortage
# 42                 not_available             not_available
# 16                          <NA>                      <NA>
# 33                 not_available             not_available
# 34                 not_available          risk_of_shortage
#
#        ipc_ppe_waterproof_aprons ipc_ppe_plan_staff_trained_on_ppe  \
# number
# 25                 not_available                     not_available
# 47                 not_available                     not_available
# 18              risk_of_shortage                     not_available
# 20                          <NA>                     not_available
# 23              risk_of_shortage                partially_achieved
# 42                 not_available                partially_achieved
# 16                          <NA>                              <NA>
# 33                 not_available                partially_achieved
# 34                 not_available                partially_achieved
#
#        ipc_ppe_plan_ppe_poster_displayed ipc_ppe_plan_fit_test_kit  \
# number
# 25                         not_available             not_available
# 47                         not_available             not_available
# 18                         not_available             not_available
# 20                         not_available             not_available
# 23                         not_available             not_available
# 42                         not_available             not_available
# 16                                  <NA>                      <NA>
# 33              available_fully_achieved             not_available
# 34              available_fully_achieved             not_available
#
#        ipc_ppe_plan_contingency_for_shortages ipc_wcd_colour_coded_bins  \
# number
# 25                         partially_achieved          risk_of_shortage
# 47                         partially_achieved          risk_of_shortage
# 18                              not_available          risk_of_shortage
# 20                              not_available          risk_of_shortage
# 23                              not_available          risk_of_shortage
# 42                              not_available          risk_of_shortage
# 16                                       <NA>                      <NA>
# 33                   available_fully_achieved       sufficient_supplies
# 34                   available_fully_achieved       sufficient_supplies
#
#        ipc_wcd_clinical_waste_bags  \
# number
# 25                risk_of_shortage
# 47                risk_of_shortage
# 18                   not_available
# 20                risk_of_shortage
# 23                risk_of_shortage
# 42                risk_of_shortage
# 16                            <NA>
# 33             sufficient_supplies
# 34                risk_of_shortage
#
#        ipc_wcd_laundry_receptacles_at_patient_rooms  ipc_wcd_incinerator  \
# number
# 25                                    not_available        not_available
# 47                                    not_available        not_available
# 18                                    not_available  sufficient_supplies
# 20                                    not_available  sufficient_supplies
# 23                                    not_available        not_available
# 42                                    not_available     risk_of_shortage
# 16                                             <NA>                 <NA>
# 33                              sufficient_supplies  sufficient_supplies
# 34                                 risk_of_shortage        not_available
#
#        ipc_wash_clean_running_water ipc_wash_hand_soap ipc_wash_liquid_soap  \
# number
# 25                 risk_of_shortage      not_available        not_available
# 47                 risk_of_shortage      not_available        not_available
# 18                 risk_of_shortage   risk_of_shortage     risk_of_shortage
# 20                 risk_of_shortage   risk_of_shortage     risk_of_shortage
# 23                 risk_of_shortage      not_available     risk_of_shortage
# 42                 risk_of_shortage   risk_of_shortage     risk_of_shortage
# 16                             <NA>               <NA>                 <NA>
# 33              sufficient_supplies      not_available        not_available
# 34                    not_available   risk_of_shortage        not_available
#
#        ipc_wash_disp_hand_towels ipc_wash_alcohol_based_hand_gel  \
# number
# 25                 not_available                   not_available
# 47                 not_available                   not_available
# 18                 not_available                risk_of_shortage
# 20                 not_available                   not_available
# 23                 not_available                risk_of_shortage
# 42                 not_available                risk_of_shortage
# 16                          <NA>                            <NA>
# 33                 not_available                   not_available
# 34                 not_available                   not_available
#
#        ipc_ds_protocol_facility_disinfection  \
# number
# 25                          risk_of_shortage
# 47                          risk_of_shortage
# 18                          risk_of_shortage
# 20                             not_available
# 23                          risk_of_shortage
# 42                          risk_of_shortage
# 16                                      <NA>
# 33                       sufficient_supplies
# 34                       sufficient_supplies
#
#        ipc_ds_protocol_equipment_sterilisation  \
# number
# 25                               not_available
# 47                               not_available
# 18                            risk_of_shortage
# 20                            risk_of_shortage
# 23                            risk_of_shortage
# 42                            risk_of_shortage
# 16                                        <NA>
# 33                               not_available
# 34                               not_available
#
#        ipc_ds_environmental_disinfectant ipc_ds_cleaning_schedule_in_toilets  \
# number
# 25                         not_available                    risk_of_shortage
# 47                         not_available                    risk_of_shortage
# 18                      risk_of_shortage                    risk_of_shortage
# 20                         not_available                       not_available
# 23                         not_available                       not_available
# 42                      risk_of_shortage                       not_available
# 16                                  <NA>                                <NA>
# 33                   sufficient_supplies                 sufficient_supplies
# 34                      risk_of_shortage                       not_available
#
#        ipc_ds_protocol_corpse_handling    log_referral_plan  \
# number
# 25                       not_available            available
# 47                       not_available            available
# 18                    risk_of_shortage        not_available
# 20                       not_available                 <NA>
# 23                       not_available        not_available
# 42                       not_available  partially_available
# 16                                <NA>                 <NA>
# 33                       not_available            available
# 34                       not_available            available
#
#        log_cellphone_landline_swradio     log_tracer_drugs  \
# number
# 25                      not_available  partially_available
# 47                      not_available        not_available
# 18                          available        not_available
# 20                               <NA>                 <NA>
# 23                      not_available  partially_available
# 42                      not_available  partially_available
# 16                               <NA>                 <NA>
# 33                partially_available                 <NA>
# 34                          available                 <NA>
#
#             log_albendazole      log_amoxicillin       log_ampicillin  \
# number
# 25                available  partially_available  partially_available
# 47                available  partially_available  partially_available
# 18      partially_available        not_available        not_available
# 20                     <NA>                 <NA>                 <NA>
# 23            not_available            available        not_available
# 42      partially_available  partially_available        not_available
# 16                     <NA>                 <NA>                 <NA>
# 33      partially_available        not_available        not_available
# 34                available  partially_available        not_available
#
#         log_chlorhexidine_5  log_chlorhexidine_7       log_gentamicin  \
# number
# 25      partially_available        not_available  partially_available
# 47      partially_available        not_available  partially_available
# 18            not_available        not_available  partially_available
# 20                     <NA>                 <NA>                 <NA>
# 23                available        not_available            available
# 42            not_available  partially_available        not_available
# 16                     <NA>                 <NA>                 <NA>
# 33            not_available        not_available        not_available
# 34      partially_available        not_available  partially_available
#
#             log_folic log_ferrous_and_folic  log_compound_sodium  \
# number
# 25      not_available         not_available        not_available
# 47      not_available         not_available        not_available
# 18      not_available         not_available        not_available
# 20               <NA>                  <NA>                 <NA>
# 23      not_available         not_available        not_available
# 42      not_available         not_available  partially_available
# 16               <NA>                  <NA>                 <NA>
# 33      not_available         not_available        not_available
# 34      not_available         not_available        not_available
#
#        log_co_trimoxazole_400 log_co_trimoxazole_200 log_metronidazole_250  \
# number
# 25              not_available          not_available   partially_available
# 47              not_available          not_available   partially_available
# 18        partially_available          not_available   partially_available
# 20                       <NA>                   <NA>                  <NA>
# 23                  available          not_available             available
# 42              not_available          not_available         not_available
# 16                       <NA>                   <NA>                  <NA>
# 33        partially_available    partially_available         not_available
# 34              not_available    partially_available         not_available
#
#        log_metronidazole_200       log_methyldopa log_magnesium_sulphate  \
# number
# 25             not_available  partially_available    partially_available
# 47             not_available  partially_available    partially_available
# 18             not_available        not_available          not_available
# 20                      <NA>                 <NA>                   <NA>
# 23             not_available            available              available
# 42             not_available        not_available    partially_available
# 16                      <NA>                 <NA>                   <NA>
# 33             not_available        not_available              available
# 34             not_available            available              available
#
#               log_lidocaine        log_ibuprofen  log_surgical_spirit  \
# number
# 25      partially_available        not_available        not_available
# 47      partially_available        not_available        not_available
# 18      partially_available  partially_available            available
# 20                     <NA>                 <NA>                 <NA>
# 23                available            available        not_available
# 42            not_available  partially_available        not_available
# 16                     <NA>                 <NA>                 <NA>
# 33      partially_available        not_available  partially_available
# 34      partially_available            available        not_available
#
#         log_sodium_chloride         log_povidone  log_paracetamol_500  \
# number
# 25      partially_available        not_available        not_available
# 47      partially_available        not_available        not_available
# 18            not_available            available        not_available
# 20                     <NA>                 <NA>                 <NA>
# 23            not_available            available            available
# 42      partially_available        not_available  partially_available
# 16                     <NA>                 <NA>                 <NA>
# 33            not_available  partially_available        not_available
# 34                available            available            available
#
#         log_paracetamol_250              log_ors            log_gauze  \
# number
# 25            not_available  partially_available        not_available
# 47            not_available  partially_available        not_available
# ...
# number
# 25                                                  16.50
# 47                                                  16.50
# 18                                                  38.50
# 20                                                    NaN
# 23                                                  29.50
# 42                                                  30.50
# 16                                                  19.50
# 33                                                  35.75
# 34                                                  12.25
#
#         score_human_resources  score_max_human_resources  \
# number
# 25                        0.5                        5.0
# 47                        0.5                        5.0
# 18                        1.0                        5.0
# 20                        0.0                        5.0
# 23                        2.0                        5.0
# 42                        2.0                        5.0
# 16                        NaN                        NaN
# 33                        2.0                        5.0
# 34                        2.5                        5.0
#
#         score_information_education_communication  \
# number
# 25                                            1.0
# 47                                            1.0
# 18                                            1.0
# 20                                            1.0
# 23                                            6.0
# 42                                            6.0
# 16                                            NaN
# 33                                            3.0
# 34                                            1.0
#
#         score_max_information_education_communication  score_surveillance  \
# number
# 25                                                7.0                 0.5
# 47                                                7.0                 2.0
# 18                                                7.0                 3.0
# 20                                                7.0                 1.5
# 23                                                7.0                 3.0
# 42                                                7.0                 2.5
# 16                                                NaN                 NaN
# 33                                                7.0                 3.0
# 34                                                7.0                 3.0
#
#         score_max_surveillance  score_triage_and_early_recognition  \
# number
# 25                         4.0                                 1.0
# 47                         4.0                                 1.5
# 18                         4.0                                 3.5
# 20                         4.0                                 0.5
# 23                         4.0                                 0.0
# 42                         4.0                                 3.5
# 16                         NaN                                 NaN
# 33                         4.0                                 3.5
# 34                         4.0                                 1.5
#
#         score_max_triage_and_early_recognition  score_chw  score_max_chw  \
# number
# 25                                         5.0        0.5            6.0
# 47                                         5.0        0.0            6.0
# 18                                         5.0        3.0            6.0
# 20                                         5.0        0.0            6.0
# 23                                         5.0        1.5            6.0
# 42                                         5.0        2.5            6.0
# 16                                         NaN        NaN            NaN
# 33                                         5.0        2.5            6.0
# 34                                         5.0        1.0            6.0
#
#         score_isolation  score_max_isolation  \
# number
# 25                  3.0                  4.0
# 47                  3.0                  4.0
# 18                  2.0                  4.0
# 20                  2.0                  4.0
# 23                  0.5                  4.0
# 42                  0.0                  4.0
# 16                  NaN                  NaN
# 33                  3.5                  4.0
# 34                  2.0                  4.0
#
#         score_infection_prevention_and_control_ppe  \
# number
# 25                                             1.0
# 47                                             1.0
# 18                                             2.0
# 20                                             0.0
# 23                                             2.0
# 42                                             0.5
# 16                                             NaN
# 33                                             0.0
# 34                                             4.5
#
#         score_max_infection_prevention_and_control_ppe  \
# number
# 25                                                 9.0
# 47                                                 9.0
# 18                                                 9.0
# 20                                                 9.0
# 23                                                 9.0
# 42                                                 9.0
# 16                                                 NaN
# 33                                                 9.0
# 34                                                 9.0
#
#         score_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                  0.5
# 47                                                  0.5
# 18                                                  0.0
# 20                                                  0.0
# 23                                                  0.5
# 42                                                  0.5
# 16                                                  NaN
# 33                                                  2.5
# 34                                                  2.5
#
#         score_max_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                    4.0
# 47                                                    4.0
# 18                                                    4.0
# 20                                                    4.0
# 23                                                    4.0
# 42                                                    4.0
# 16                                                    NaN
# 33                                                    4.0
# 34                                                    4.0
#
#         score_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    1.0
# 47                                                    1.0
# 18                                                    1.5
# 20                                                    2.0
# 23                                                    1.0
# 42                                                    1.5
# 16                                                    NaN
# 33                                                    4.0
# 34                                                    2.0
#
#         score_max_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    4.0
# 47                                                    4.0
# 18                                                    4.0
# 20                                                    4.0
# 23                                                    4.0
# 42                                                    4.0
# 16                                                    NaN
# 33                                                    4.0
# 34                                                    4.0
#
#         score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    0.5
# 47                                                    0.5
# 18                                                    2.0
# 20                                                    1.5
# 23                                                    1.5
# 42                                                    2.0
# 16                                                    NaN
# 33                                                    1.0
# 34                                                    0.5
#
#         score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    5.0
# 47                                                    5.0
# 18                                                    5.0
# 20                                                    5.0
# 23                                                    5.0
# 42                                                    5.0
# 16                                                    NaN
# 33                                                    5.0
# 34                                                    5.0
#
#         score_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    0.5
# 47                                                    0.5
# 18                                                    2.0
# 20                                                    0.5
# 23                                                    1.0
# 42                                                    1.5
# 16                                                    NaN
# 33                                                    2.0
# 34                                                    1.5
#
#         score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    5.0
# 47                                                    5.0
# 18                                                    5.0
# 20                                                    5.0
# 23                                                    5.0
# 42                                                    5.0
# 16                                                    NaN
# 33                                                    5.0
# 34                                                    5.0
#
#         score_infection_prevention_and_control  \
# number
# 25                                         3.5
# 47                                         3.5
# 18                                         7.5
# 20                                         4.0
# 23                                         6.0
# 42                                         6.0
# 16                                         NaN
# 33                                         9.5
# 34                                        11.0
#
#         score_max_infection_prevention_and_control  \
# number
# 25                                            27.0
# 47                                            27.0
# 18                                            27.0
# 20                                            27.0
# 23                                            27.0
# 42                                            27.0
# 16                                             NaN
# 33                                            27.0
# 34                                            27.0
#
#         question1.score_logistics_patient_and_sample_transfer  \
# number
# 25                                                   12.0
# 47                                                   11.0
# 18                                                   11.0
# 20                                                    0.0
# 23                                                   18.0
# 42                                                    9.5
# 16                                                    NaN
# 33                                                   11.0
# 34                                                   18.5
#
#         question1.score_max_logistics_patient_and_sample_transfer  \
# number
# 25                                                   44.0
# 47                                                   44.0
# 18                                                   44.0
# 20                                                   44.0
# 23                                                   44.0
# 42                                                   44.0
# 16                                                    NaN
# 33                                                   44.0
# 34                                                   44.0
#
#         score_total  score_max_total
# number
# 25             22.0            102.0
# 47             22.5            102.0
# 18             32.0            102.0
# 20              9.0            102.0
# 23             37.0            102.0
# 42             32.0            102.0
# 16              0.0              0.0
# 33             38.0            102.0
# 34             40.5            102.0

# %% [markdown]
# From the above, it looks like there are no cases where facilities in the same location have two slightly different names.

# %% [markdown]
# It is also possible that some of the duplicate facility names refer to independent clinics that happen to have the same name. Let's also consider the number of consultations in the facility to get a clearer picture.

# %%
df_dup_2 = df[df.duplicated(['facility_name','consultations.head_count.month_1','consultations.head_count.month_2','consultations.head_count.month_3','consultations.head_count.month_4'],keep=False)].sort_values('facility_name')
df_dup_2
# Out:
#         facility_name  facility_gps_lat  facility_gps_lon region_province  \
# number
# 25      JOANNA CLINIC         15.754015       -153.871776        SOUTHERN
# 47      JOANNA CLINIC         60.190934        162.787117        SOUTHERN
#
#        district     chiefdom facility_location facility_type  \
# number
# 25           BO  MISSISSIPPI      AMBERCHESTER      mch_post
# 47           BO  MISSISSIPPI      AMBERCHESTER      mch_post
#
#        facility_type_other managing_authority managing_authority_other  \
# number
# 25                    <NA>  government_public                     <NA>
# 47                    <NA>  government_public                     <NA>
#
#            setting  outpatient_only  capacity.number_consultation_rooms  \
# number
# 25           rural             True                                   1
# 47      peri_urban             True                                   1
#
#         capacity.number_inpatient_beds  capacity.number_maternity_beds  \
# number
# 25                                   2                               1
# 47                                   2                               1
#
#         cho_number_in_post  cho_number_present_at_visit  cht_number_in_post  \
# number
# 25                       0                            0                   0
# 47                       0                            0                   0
#
#         cht_number_present_at_visit  cha_number_in_post  \
# number
# 25                                0                   0
# 47                                0                   0
#
#         cha_number_present_at_visit  cm_number_in_post  \
# number
# 25                                0                  0
# 47                                0                  0
#
#         cm_number_present_at_visit  sechn_number_in_post  \
# number
# 25                               0                     0
# 47                               0                     0
#
#         sechn_number_present_at_visit  lab_tech_number_in_post  \
# number
# 25                                  0                        0
# 47                                  0                        0
#
#         lab_tech_number_present_at_visit  mch_aides_number_in_post  \
# number
# 25                                     0                         3
# 47                                     0                         3
#
#         mch_aides_number_present_at_visit  cleaner_porter_number_in_post  \
# number
# 25                                      2                              1
# 47                                      2                              1
#
#         cleaner_porter_number_present_at_visit  other_number_in_post  \
# number
# 25                                           1                     4
# 47                                           1                     4
#
#         other_number_present_at_visit other_staff_cadre  \
# number
# 25                                  0             TBA's
# 47                                  0             TBA's
#
#                                        sections_to_review  \
# number
# 25      consultations hr information_education_communi...
# 47      consultations hr information_education_communi...
#
#         consultations.head_count.month_1  consultations.head_count.month_2  \
# number
# 25                                   388                               153
# 47                                   388                               153
#
#         consultations.head_count.month_3  consultations.head_count.month_4  \
# number
# 25                                   180                               183
# 47                                   180                               183
#
#         consultations.general_outpatient.month_1  \
# number
# 25                                           133
# 47                                           133
#
#         consultations.general_outpatient.month_2  \
# number
# 25                                            30
# 47                                            30
#
#         consultations.general_outpatient.month_3  \
# number
# 25                                            21
# 47                                            21
#
#         consultations.general_outpatient.month_4  \
# number
# 25                                            55
# 47                                            55
#
#         consultations.deliveries.month_1  consultations.deliveries.month_2  \
# number
# 25                                    18                                10
# 47                                    18                                10
#
#         consultations.deliveries.month_3  consultations.deliveries.month_4  \
# number
# 25                                    14                                14
# 47                                    14                                14
#
#         consultations.pent_vaccines.month_1  \
# number
# 25                                       17
# 47                                       17
#
#         consultations.pent_vaccines.month_2  \
# number
# 25                                       18
# 47                                       18
#
#         consultations.pent_vaccines.month_3  \
# number
# 25                                       12
# 47                                       12
#
#         consultations.pent_vaccines.month_4 hr_focal_point  \
# number
# 25                                       19  not_completed
# 47                                       19  not_completed
#
#        hr_staff_received_info hr_healthcare_provider_training  \
# number
# 25        partially_completed                   not_completed
# 47        partially_completed                   not_completed
#
#        hr_healthcare_provider_revised_training hr_daily_staff_list  \
# number
# 25                               not_completed       not_completed
# 47                               not_completed       not_completed
#
#        iec_handwashing_procedure iec_physical_distancing  \
# number
# 25                 not_displayed           not_displayed
# 47                 not_displayed           not_displayed
#
#        iec_covering_nose_mouth iec_early_symptom_recognition  \
# number
# 25               not_displayed                 not_displayed
# 47               not_displayed                 not_displayed
#
#        iec_when_facility_vs_home iec_rational_ppe_use iec_helpline_number  \
# number
# 25                 not_displayed            displayed       not_displayed
# 47                 not_displayed            displayed       not_displayed
#
#        surv_procedure_for_notification surv_official_case_definition  \
# number
# 25                        not_in_place                  not_in_place
# 47                        not_in_place                  not_in_place
#
#           surv_hotline_number surv_timely_data_reported_to_district  \
# number
# 25      partially_operational                          not_in_place
# 47          fully_operational                     fully_operational
#
#        ter_screening_area_set_up ter_symptom_screening_questionnaires  \
# number
# 25                  not_in_place                         not_in_place
# 47         partially_operational                         not_in_place
#
#        ter_temperature_measurement_at_triage  \
# number
# 25                              not_in_place
# 47                              not_in_place
#
#        ter_physical_distancing_in_waiting  \
# number
# 25                      fully_operational
# 47                      fully_operational
#
#        ter_separate_waiting_for_symptomatic chw_trained_precautions  \
# number
# 25                             not_in_place            not_in_place
# 47                             not_in_place            not_in_place
#
#        chw_trained_community_service     chw_drugs    chw_gloves  \
# number
# 25                      not_in_place       partial  not_in_place
# 47                      not_in_place  not_in_place  not_in_place
#
#            chw_masks chw_iec_materials iso_designated_isolation_for_suspected  \
# number
# 25              <NA>      not_in_place                           not_in_place
# 47      not_in_place      not_in_place                           not_in_place
#
#        iso_distance_between_patients_in_waiting  \
# number
# 25                            fully_operational
# 47                            fully_operational
#
#        iso_distance_between_patient_beds iso_transfer_referral_protocol  \
# number
# 25                     fully_operational              fully_operational
# 47                     fully_operational              fully_operational
#
#        ipc_ppe_medical_masks ipc_ppe_disp_surgical_masks  \
# number
# 25          risk_of_shortage               not_available
# 47          risk_of_shortage               not_available
#
#        ipc_ppe_eye_protection ipc_ppe_examination_gloves  \
# number
# 25              not_available           risk_of_shortage
# 47              not_available           risk_of_shortage
#
#        ipc_ppe_surgical_gloves ipc_ppe_long_cuffed_gloves  \
# number
# 25               not_available              not_available
# 47               not_available              not_available
#
#        ipc_ppe_heavy_duty_gloves ipc_ppe_long_sleeved_gown  \
# number
# 25                 not_available             not_available
# 47                 not_available             not_available
#
#        ipc_ppe_waterproof_aprons ipc_ppe_plan_staff_trained_on_ppe  \
# number
# 25                 not_available                     not_available
# 47                 not_available                     not_available
#
#        ipc_ppe_plan_ppe_poster_displayed ipc_ppe_plan_fit_test_kit  \
# number
# 25                         not_available             not_available
# 47                         not_available             not_available
#
#        ipc_ppe_plan_contingency_for_shortages ipc_wcd_colour_coded_bins  \
# number
# 25                         partially_achieved          risk_of_shortage
# 47                         partially_achieved          risk_of_shortage
#
#        ipc_wcd_clinical_waste_bags  \
# number
# 25                risk_of_shortage
# 47                risk_of_shortage
#
#        ipc_wcd_laundry_receptacles_at_patient_rooms ipc_wcd_incinerator  \
# number
# 25                                    not_available       not_available
# 47                                    not_available       not_available
#
#        ipc_wash_clean_running_water ipc_wash_hand_soap ipc_wash_liquid_soap  \
# number
# 25                 risk_of_shortage      not_available        not_available
# 47                 risk_of_shortage      not_available        not_available
#
#        ipc_wash_disp_hand_towels ipc_wash_alcohol_based_hand_gel  \
# number
# 25                 not_available                   not_available
# 47                 not_available                   not_available
#
#        ipc_ds_protocol_facility_disinfection  \
# number
# 25                          risk_of_shortage
# 47                          risk_of_shortage
#
#        ipc_ds_protocol_equipment_sterilisation  \
# number
# 25                               not_available
# 47                               not_available
#
#        ipc_ds_environmental_disinfectant ipc_ds_cleaning_schedule_in_toilets  \
# number
# 25                         not_available                    risk_of_shortage
# 47                         not_available                    risk_of_shortage
#
#        ipc_ds_protocol_corpse_handling log_referral_plan  \
# number
# 25                       not_available         available
# 47                       not_available         available
#
#        log_cellphone_landline_swradio     log_tracer_drugs log_albendazole  \
# number
# 25                      not_available  partially_available       available
# 47                      not_available        not_available       available
#
#             log_amoxicillin       log_ampicillin  log_chlorhexidine_5  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_chlorhexidine_7       log_gentamicin      log_folic  \
# number
# 25           not_available  partially_available  not_available
# 47           not_available  partially_available  not_available
#
#        log_ferrous_and_folic log_compound_sodium log_co_trimoxazole_400  \
# number
# 25             not_available       not_available          not_available
# 47             not_available       not_available          not_available
#
#        log_co_trimoxazole_200 log_metronidazole_250 log_metronidazole_200  \
# number
# 25              not_available   partially_available         not_available
# 47              not_available   partially_available         not_available
#
#              log_methyldopa log_magnesium_sulphate        log_lidocaine  \
# number
# 25      partially_available    partially_available  partially_available
# 47      partially_available    partially_available  partially_available
#
#         log_ibuprofen log_surgical_spirit  log_sodium_chloride   log_povidone  \
# number
# 25      not_available       not_available  partially_available  not_available
# 47      not_available       not_available  partially_available  not_available
#
#        log_paracetamol_500 log_paracetamol_250              log_ors  \
# number
# 25           not_available       not_available  partially_available
# 47           not_available       not_available  partially_available
#
#             log_gauze      log_cotton_wool log_cannula_iv_20  \
# number
# 25      not_available  partially_available     not_available
# 47      not_available  partially_available     not_available
#
#        log_cannula_iv_24    log_zinc_sulphate            log_water  \
# number
# 25         not_available  partially_available  partially_available
# 47         not_available  partially_available  partially_available
#
#               log_needle_23  log_needle_21     log_glove_giving  \
# number
# 25      partially_available  not_available  partially_available
# 47      partially_available  not_available  partially_available
#
#          log_glove_surgical  log_glove_gyn       log_glove_exam  \
# number
# 25      partially_available  not_available  partially_available
# 47            not_available  not_available  partially_available
#
#                    log_tape          log_syringe         log_oxytocin  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_diazepam log_misoprostol    log_glucose  \
# number
# 25        available   not_available  not_available
# 47        available   not_available  not_available
#
#         consultations.head_count.monthly_average_head_counts  \
# number
# 25                                                  226.0
# 47                                                  226.0
#
#         consultations.general_outpatient.monthly_average_general_outpatient  \
# number
# 25                                                  59.75
# 47                                                  59.75
#
#         consultations.deliveries.monthly_average_deliveries  \
# number
# 25                                                   14.0
# 47                                                   14.0
#
#         consultations.pent_vaccines.monthly_average_pent_vaccines  \
# number
# 25                                                   16.5
# 47                                                   16.5
#
#         score_human_resources  score_max_human_resources  \
# number
# 25                        0.5                        5.0
# 47                        0.5                        5.0
#
#         score_information_education_communication  \
# number
# 25                                            1.0
# 47                                            1.0
#
#         score_max_information_education_communication  score_surveillance  \
# number
# 25                                                7.0                 0.5
# 47                                                7.0                 2.0
#
#         score_max_surveillance  score_triage_and_early_recognition  \
# number
# 25                         4.0                                 1.0
# 47                         4.0                                 1.5
#
#         score_max_triage_and_early_recognition  score_chw  score_max_chw  \
# number
# 25                                         5.0        0.5            6.0
# 47                                         5.0        0.0            6.0
#
#         score_isolation  score_max_isolation  \
# number
# 25                  3.0                  4.0
# 47                  3.0                  4.0
#
#         score_infection_prevention_and_control_ppe  \
# number
# 25                                             1.0
# 47                                             1.0
#
#         score_max_infection_prevention_and_control_ppe  \
# number
# 25                                                 9.0
# 47                                                 9.0
#
#         score_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                  0.5
# 47                                                  0.5
#
#         score_max_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    1.0
# 47                                                    1.0
#
#         score_max_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control  \
# number
# 25                                         3.5
# 47                                         3.5
#
#         score_max_infection_prevention_and_control  \
# number
# 25                                            27.0
# 47                                            27.0
#
#         question1.score_logistics_patient_and_sample_transfer  \
# number
# 25                                                   12.0
# 47                                                   11.0
#
#         question1.score_max_logistics_patient_and_sample_transfer  \
# number
# 25                                                   44.0
# 47                                                   44.0
#
#         score_total  score_max_total
# number
# 25             22.0            102.0
# 47             22.5            102.0

# %% [markdown]
# It's very unlikely that the consultation headcount numbers for four months would be exactly the same between two identically named clinics. These are therefore likely to truly refer to the same facility.

# %%
len(df_dup_2)
# Out:
# 2

# %% [markdown]
# Our number of duplicates has now dropped lower. But maybe there are still some very similar entries where one or more of the consultation headcounts differ. We have not recorded those in df_dup_2. Let's search for matches with regard to a number of different column combinations and merge the resulting dataframes into one.
#
# We consider matching facility names and facility locations first.

# %%
df_dup_3 = df[df.duplicated(['facility_name','facility_location'],keep=False)].sort_values('facility_name')
df_dup_3
# Out:
#         facility_name  facility_gps_lat  facility_gps_lon region_province  \
# number
# 25      JOANNA CLINIC         15.754015       -153.871776        SOUTHERN
# 47      JOANNA CLINIC         60.190934        162.787117        SOUTHERN
#
#        district     chiefdom facility_location facility_type  \
# number
# 25           BO  MISSISSIPPI      AMBERCHESTER      mch_post
# 47           BO  MISSISSIPPI      AMBERCHESTER      mch_post
#
#        facility_type_other managing_authority managing_authority_other  \
# number
# 25                    <NA>  government_public                     <NA>
# 47                    <NA>  government_public                     <NA>
#
#            setting  outpatient_only  capacity.number_consultation_rooms  \
# number
# 25           rural             True                                   1
# 47      peri_urban             True                                   1
#
#         capacity.number_inpatient_beds  capacity.number_maternity_beds  \
# number
# 25                                   2                               1
# 47                                   2                               1
#
#         cho_number_in_post  cho_number_present_at_visit  cht_number_in_post  \
# number
# 25                       0                            0                   0
# 47                       0                            0                   0
#
#         cht_number_present_at_visit  cha_number_in_post  \
# number
# 25                                0                   0
# 47                                0                   0
#
#         cha_number_present_at_visit  cm_number_in_post  \
# number
# 25                                0                  0
# 47                                0                  0
#
#         cm_number_present_at_visit  sechn_number_in_post  \
# number
# 25                               0                     0
# 47                               0                     0
#
#         sechn_number_present_at_visit  lab_tech_number_in_post  \
# number
# 25                                  0                        0
# 47                                  0                        0
#
#         lab_tech_number_present_at_visit  mch_aides_number_in_post  \
# number
# 25                                     0                         3
# 47                                     0                         3
#
#         mch_aides_number_present_at_visit  cleaner_porter_number_in_post  \
# number
# 25                                      2                              1
# 47                                      2                              1
#
#         cleaner_porter_number_present_at_visit  other_number_in_post  \
# number
# 25                                           1                     4
# 47                                           1                     4
#
#         other_number_present_at_visit other_staff_cadre  \
# number
# 25                                  0             TBA's
# 47                                  0             TBA's
#
#                                        sections_to_review  \
# number
# 25      consultations hr information_education_communi...
# 47      consultations hr information_education_communi...
#
#         consultations.head_count.month_1  consultations.head_count.month_2  \
# number
# 25                                   388                               153
# 47                                   388                               153
#
#         consultations.head_count.month_3  consultations.head_count.month_4  \
# number
# 25                                   180                               183
# 47                                   180                               183
#
#         consultations.general_outpatient.month_1  \
# number
# 25                                           133
# 47                                           133
#
#         consultations.general_outpatient.month_2  \
# number
# 25                                            30
# 47                                            30
#
#         consultations.general_outpatient.month_3  \
# number
# 25                                            21
# 47                                            21
#
#         consultations.general_outpatient.month_4  \
# number
# 25                                            55
# 47                                            55
#
#         consultations.deliveries.month_1  consultations.deliveries.month_2  \
# number
# 25                                    18                                10
# 47                                    18                                10
#
#         consultations.deliveries.month_3  consultations.deliveries.month_4  \
# number
# 25                                    14                                14
# 47                                    14                                14
#
#         consultations.pent_vaccines.month_1  \
# number
# 25                                       17
# 47                                       17
#
#         consultations.pent_vaccines.month_2  \
# number
# 25                                       18
# 47                                       18
#
#         consultations.pent_vaccines.month_3  \
# number
# 25                                       12
# 47                                       12
#
#         consultations.pent_vaccines.month_4 hr_focal_point  \
# number
# 25                                       19  not_completed
# 47                                       19  not_completed
#
#        hr_staff_received_info hr_healthcare_provider_training  \
# number
# 25        partially_completed                   not_completed
# 47        partially_completed                   not_completed
#
#        hr_healthcare_provider_revised_training hr_daily_staff_list  \
# number
# 25                               not_completed       not_completed
# 47                               not_completed       not_completed
#
#        iec_handwashing_procedure iec_physical_distancing  \
# number
# 25                 not_displayed           not_displayed
# 47                 not_displayed           not_displayed
#
#        iec_covering_nose_mouth iec_early_symptom_recognition  \
# number
# 25               not_displayed                 not_displayed
# 47               not_displayed                 not_displayed
#
#        iec_when_facility_vs_home iec_rational_ppe_use iec_helpline_number  \
# number
# 25                 not_displayed            displayed       not_displayed
# 47                 not_displayed            displayed       not_displayed
#
#        surv_procedure_for_notification surv_official_case_definition  \
# number
# 25                        not_in_place                  not_in_place
# 47                        not_in_place                  not_in_place
#
#           surv_hotline_number surv_timely_data_reported_to_district  \
# number
# 25      partially_operational                          not_in_place
# 47          fully_operational                     fully_operational
#
#        ter_screening_area_set_up ter_symptom_screening_questionnaires  \
# number
# 25                  not_in_place                         not_in_place
# 47         partially_operational                         not_in_place
#
#        ter_temperature_measurement_at_triage  \
# number
# 25                              not_in_place
# 47                              not_in_place
#
#        ter_physical_distancing_in_waiting  \
# number
# 25                      fully_operational
# 47                      fully_operational
#
#        ter_separate_waiting_for_symptomatic chw_trained_precautions  \
# number
# 25                             not_in_place            not_in_place
# 47                             not_in_place            not_in_place
#
#        chw_trained_community_service     chw_drugs    chw_gloves  \
# number
# 25                      not_in_place       partial  not_in_place
# 47                      not_in_place  not_in_place  not_in_place
#
#            chw_masks chw_iec_materials iso_designated_isolation_for_suspected  \
# number
# 25              <NA>      not_in_place                           not_in_place
# 47      not_in_place      not_in_place                           not_in_place
#
#        iso_distance_between_patients_in_waiting  \
# number
# 25                            fully_operational
# 47                            fully_operational
#
#        iso_distance_between_patient_beds iso_transfer_referral_protocol  \
# number
# 25                     fully_operational              fully_operational
# 47                     fully_operational              fully_operational
#
#        ipc_ppe_medical_masks ipc_ppe_disp_surgical_masks  \
# number
# 25          risk_of_shortage               not_available
# 47          risk_of_shortage               not_available
#
#        ipc_ppe_eye_protection ipc_ppe_examination_gloves  \
# number
# 25              not_available           risk_of_shortage
# 47              not_available           risk_of_shortage
#
#        ipc_ppe_surgical_gloves ipc_ppe_long_cuffed_gloves  \
# number
# 25               not_available              not_available
# 47               not_available              not_available
#
#        ipc_ppe_heavy_duty_gloves ipc_ppe_long_sleeved_gown  \
# number
# 25                 not_available             not_available
# 47                 not_available             not_available
#
#        ipc_ppe_waterproof_aprons ipc_ppe_plan_staff_trained_on_ppe  \
# number
# 25                 not_available                     not_available
# 47                 not_available                     not_available
#
#        ipc_ppe_plan_ppe_poster_displayed ipc_ppe_plan_fit_test_kit  \
# number
# 25                         not_available             not_available
# 47                         not_available             not_available
#
#        ipc_ppe_plan_contingency_for_shortages ipc_wcd_colour_coded_bins  \
# number
# 25                         partially_achieved          risk_of_shortage
# 47                         partially_achieved          risk_of_shortage
#
#        ipc_wcd_clinical_waste_bags  \
# number
# 25                risk_of_shortage
# 47                risk_of_shortage
#
#        ipc_wcd_laundry_receptacles_at_patient_rooms ipc_wcd_incinerator  \
# number
# 25                                    not_available       not_available
# 47                                    not_available       not_available
#
#        ipc_wash_clean_running_water ipc_wash_hand_soap ipc_wash_liquid_soap  \
# number
# 25                 risk_of_shortage      not_available        not_available
# 47                 risk_of_shortage      not_available        not_available
#
#        ipc_wash_disp_hand_towels ipc_wash_alcohol_based_hand_gel  \
# number
# 25                 not_available                   not_available
# 47                 not_available                   not_available
#
#        ipc_ds_protocol_facility_disinfection  \
# number
# 25                          risk_of_shortage
# 47                          risk_of_shortage
#
#        ipc_ds_protocol_equipment_sterilisation  \
# number
# 25                               not_available
# 47                               not_available
#
#        ipc_ds_environmental_disinfectant ipc_ds_cleaning_schedule_in_toilets  \
# number
# 25                         not_available                    risk_of_shortage
# 47                         not_available                    risk_of_shortage
#
#        ipc_ds_protocol_corpse_handling log_referral_plan  \
# number
# 25                       not_available         available
# 47                       not_available         available
#
#        log_cellphone_landline_swradio     log_tracer_drugs log_albendazole  \
# number
# 25                      not_available  partially_available       available
# 47                      not_available        not_available       available
#
#             log_amoxicillin       log_ampicillin  log_chlorhexidine_5  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_chlorhexidine_7       log_gentamicin      log_folic  \
# number
# 25           not_available  partially_available  not_available
# 47           not_available  partially_available  not_available
#
#        log_ferrous_and_folic log_compound_sodium log_co_trimoxazole_400  \
# number
# 25             not_available       not_available          not_available
# 47             not_available       not_available          not_available
#
#        log_co_trimoxazole_200 log_metronidazole_250 log_metronidazole_200  \
# number
# 25              not_available   partially_available         not_available
# 47              not_available   partially_available         not_available
#
#              log_methyldopa log_magnesium_sulphate        log_lidocaine  \
# number
# 25      partially_available    partially_available  partially_available
# 47      partially_available    partially_available  partially_available
#
#         log_ibuprofen log_surgical_spirit  log_sodium_chloride   log_povidone  \
# number
# 25      not_available       not_available  partially_available  not_available
# 47      not_available       not_available  partially_available  not_available
#
#        log_paracetamol_500 log_paracetamol_250              log_ors  \
# number
# 25           not_available       not_available  partially_available
# 47           not_available       not_available  partially_available
#
#             log_gauze      log_cotton_wool log_cannula_iv_20  \
# number
# 25      not_available  partially_available     not_available
# 47      not_available  partially_available     not_available
#
#        log_cannula_iv_24    log_zinc_sulphate            log_water  \
# number
# 25         not_available  partially_available  partially_available
# 47         not_available  partially_available  partially_available
#
#               log_needle_23  log_needle_21     log_glove_giving  \
# number
# 25      partially_available  not_available  partially_available
# 47      partially_available  not_available  partially_available
#
#          log_glove_surgical  log_glove_gyn       log_glove_exam  \
# number
# 25      partially_available  not_available  partially_available
# 47            not_available  not_available  partially_available
#
#                    log_tape          log_syringe         log_oxytocin  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_diazepam log_misoprostol    log_glucose  \
# number
# 25        available   not_available  not_available
# 47        available   not_available  not_available
#
#         consultations.head_count.monthly_average_head_counts  \
# number
# 25                                                  226.0
# 47                                                  226.0
#
#         consultations.general_outpatient.monthly_average_general_outpatient  \
# number
# 25                                                  59.75
# 47                                                  59.75
#
#         consultations.deliveries.monthly_average_deliveries  \
# number
# 25                                                   14.0
# 47                                                   14.0
#
#         consultations.pent_vaccines.monthly_average_pent_vaccines  \
# number
# 25                                                   16.5
# 47                                                   16.5
#
#         score_human_resources  score_max_human_resources  \
# number
# 25                        0.5                        5.0
# 47                        0.5                        5.0
#
#         score_information_education_communication  \
# number
# 25                                            1.0
# 47                                            1.0
#
#         score_max_information_education_communication  score_surveillance  \
# number
# 25                                                7.0                 0.5
# 47                                                7.0                 2.0
#
#         score_max_surveillance  score_triage_and_early_recognition  \
# number
# 25                         4.0                                 1.0
# 47                         4.0                                 1.5
#
#         score_max_triage_and_early_recognition  score_chw  score_max_chw  \
# number
# 25                                         5.0        0.5            6.0
# 47                                         5.0        0.0            6.0
#
#         score_isolation  score_max_isolation  \
# number
# 25                  3.0                  4.0
# 47                  3.0                  4.0
#
#         score_infection_prevention_and_control_ppe  \
# number
# 25                                             1.0
# 47                                             1.0
#
#         score_max_infection_prevention_and_control_ppe  \
# number
# 25                                                 9.0
# 47                                                 9.0
#
#         score_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                  0.5
# 47                                                  0.5
#
#         score_max_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    1.0
# 47                                                    1.0
#
#         score_max_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control  \
# number
# 25                                         3.5
# 47                                         3.5
#
#         score_max_infection_prevention_and_control  \
# number
# 25                                            27.0
# 47                                            27.0
#
#         question1.score_logistics_patient_and_sample_transfer  \
# number
# 25                                                   12.0
# 47                                                   11.0
#
#         question1.score_max_logistics_patient_and_sample_transfer  \
# number
# 25                                                   44.0
# 47                                                   44.0
#
#         score_total  score_max_total
# number
# 25             22.0            102.0
# 47             22.5            102.0

# %%
len(df_dup_3)
# Out:
# 2

# %% [markdown]
# Now we consider cases where at least one of the months' consultation headcounts match. This seems unlikely enough that it's worth looking into.

# %%
# considering rows where consultation headcount month 1 matches
df_dup_4 = df[df.duplicated(['facility_name','consultations.head_count.month_1'],keep=False)].sort_values('facility_name')
# considering rows where consultation headcount month 2 matches
df_dup_5 = df[df.duplicated(['facility_name','consultations.head_count.month_2'],keep=False)].sort_values('facility_name')
# considering rows where consultation headcount month 3 matches
df_dup_6 = df[df.duplicated(['facility_name','consultations.head_count.month_3'],keep=False)].sort_values('facility_name')
# considering rows where consultation headcount month 4 matches
df_dup_7 = df[df.duplicated(['facility_name','consultations.head_count.month_4'],keep=False)].sort_values('facility_name')

# %% [markdown]
# There will be a lot of overlap among df_dup_3, df_dup_4, df_dup_5, df_dup_6, and df_dup_7. We want to save all the unique entries across these dataframes, without having extra duplicates. We start by merging the duplicate candidates into one dataframe, in the process creating lots of duplicates. Those duplicates need to be deleted later.

# %%
df_dup_potential_redundant = pd.concat([df_dup_3,df_dup_4,df_dup_5,df_dup_6,df_dup_7])

# %% [markdown]
# We now find and delete the duplicate indices.

# %%
df_dup_potential = df_dup_potential_redundant[~df_dup_potential_redundant.index.duplicated(keep='first')]
#dup_indices = df_dup_potential_redundant.index.duplicated(keep='first')
#df_dup_potential = df_dup_potential_redundant.drop(df_dup_potential_redundant[dup_indices].index)
df_dup_potential
# Out:
#         facility_name  facility_gps_lat  facility_gps_lon region_province  \
# number
# 25      JOANNA CLINIC         15.754015       -153.871776        SOUTHERN
# 47      JOANNA CLINIC         60.190934        162.787117        SOUTHERN
#
#        district     chiefdom facility_location facility_type  \
# number
# 25           BO  MISSISSIPPI      AMBERCHESTER      mch_post
# 47           BO  MISSISSIPPI      AMBERCHESTER      mch_post
#
#        facility_type_other managing_authority managing_authority_other  \
# number
# 25                    <NA>  government_public                     <NA>
# 47                    <NA>  government_public                     <NA>
#
#            setting  outpatient_only  capacity.number_consultation_rooms  \
# number
# 25           rural             True                                   1
# 47      peri_urban             True                                   1
#
#         capacity.number_inpatient_beds  capacity.number_maternity_beds  \
# number
# 25                                   2                               1
# 47                                   2                               1
#
#         cho_number_in_post  cho_number_present_at_visit  cht_number_in_post  \
# number
# 25                       0                            0                   0
# 47                       0                            0                   0
#
#         cht_number_present_at_visit  cha_number_in_post  \
# number
# 25                                0                   0
# 47                                0                   0
#
#         cha_number_present_at_visit  cm_number_in_post  \
# number
# 25                                0                  0
# 47                                0                  0
#
#         cm_number_present_at_visit  sechn_number_in_post  \
# number
# 25                               0                     0
# 47                               0                     0
#
#         sechn_number_present_at_visit  lab_tech_number_in_post  \
# number
# 25                                  0                        0
# 47                                  0                        0
#
#         lab_tech_number_present_at_visit  mch_aides_number_in_post  \
# number
# 25                                     0                         3
# 47                                     0                         3
#
#         mch_aides_number_present_at_visit  cleaner_porter_number_in_post  \
# number
# 25                                      2                              1
# 47                                      2                              1
#
#         cleaner_porter_number_present_at_visit  other_number_in_post  \
# number
# 25                                           1                     4
# 47                                           1                     4
#
#         other_number_present_at_visit other_staff_cadre  \
# number
# 25                                  0             TBA's
# 47                                  0             TBA's
#
#                                        sections_to_review  \
# number
# 25      consultations hr information_education_communi...
# 47      consultations hr information_education_communi...
#
#         consultations.head_count.month_1  consultations.head_count.month_2  \
# number
# 25                                   388                               153
# 47                                   388                               153
#
#         consultations.head_count.month_3  consultations.head_count.month_4  \
# number
# 25                                   180                               183
# 47                                   180                               183
#
#         consultations.general_outpatient.month_1  \
# number
# 25                                           133
# 47                                           133
#
#         consultations.general_outpatient.month_2  \
# number
# 25                                            30
# 47                                            30
#
#         consultations.general_outpatient.month_3  \
# number
# 25                                            21
# 47                                            21
#
#         consultations.general_outpatient.month_4  \
# number
# 25                                            55
# 47                                            55
#
#         consultations.deliveries.month_1  consultations.deliveries.month_2  \
# number
# 25                                    18                                10
# 47                                    18                                10
#
#         consultations.deliveries.month_3  consultations.deliveries.month_4  \
# number
# 25                                    14                                14
# 47                                    14                                14
#
#         consultations.pent_vaccines.month_1  \
# number
# 25                                       17
# 47                                       17
#
#         consultations.pent_vaccines.month_2  \
# number
# 25                                       18
# 47                                       18
#
#         consultations.pent_vaccines.month_3  \
# number
# 25                                       12
# 47                                       12
#
#         consultations.pent_vaccines.month_4 hr_focal_point  \
# number
# 25                                       19  not_completed
# 47                                       19  not_completed
#
#        hr_staff_received_info hr_healthcare_provider_training  \
# number
# 25        partially_completed                   not_completed
# 47        partially_completed                   not_completed
#
#        hr_healthcare_provider_revised_training hr_daily_staff_list  \
# number
# 25                               not_completed       not_completed
# 47                               not_completed       not_completed
#
#        iec_handwashing_procedure iec_physical_distancing  \
# number
# 25                 not_displayed           not_displayed
# 47                 not_displayed           not_displayed
#
#        iec_covering_nose_mouth iec_early_symptom_recognition  \
# number
# 25               not_displayed                 not_displayed
# 47               not_displayed                 not_displayed
#
#        iec_when_facility_vs_home iec_rational_ppe_use iec_helpline_number  \
# number
# 25                 not_displayed            displayed       not_displayed
# 47                 not_displayed            displayed       not_displayed
#
#        surv_procedure_for_notification surv_official_case_definition  \
# number
# 25                        not_in_place                  not_in_place
# 47                        not_in_place                  not_in_place
#
#           surv_hotline_number surv_timely_data_reported_to_district  \
# number
# 25      partially_operational                          not_in_place
# 47          fully_operational                     fully_operational
#
#        ter_screening_area_set_up ter_symptom_screening_questionnaires  \
# number
# 25                  not_in_place                         not_in_place
# 47         partially_operational                         not_in_place
#
#        ter_temperature_measurement_at_triage  \
# number
# 25                              not_in_place
# 47                              not_in_place
#
#        ter_physical_distancing_in_waiting  \
# number
# 25                      fully_operational
# 47                      fully_operational
#
#        ter_separate_waiting_for_symptomatic chw_trained_precautions  \
# number
# 25                             not_in_place            not_in_place
# 47                             not_in_place            not_in_place
#
#        chw_trained_community_service     chw_drugs    chw_gloves  \
# number
# 25                      not_in_place       partial  not_in_place
# 47                      not_in_place  not_in_place  not_in_place
#
#            chw_masks chw_iec_materials iso_designated_isolation_for_suspected  \
# number
# 25              <NA>      not_in_place                           not_in_place
# 47      not_in_place      not_in_place                           not_in_place
#
#        iso_distance_between_patients_in_waiting  \
# number
# 25                            fully_operational
# 47                            fully_operational
#
#        iso_distance_between_patient_beds iso_transfer_referral_protocol  \
# number
# 25                     fully_operational              fully_operational
# 47                     fully_operational              fully_operational
#
#        ipc_ppe_medical_masks ipc_ppe_disp_surgical_masks  \
# number
# 25          risk_of_shortage               not_available
# 47          risk_of_shortage               not_available
#
#        ipc_ppe_eye_protection ipc_ppe_examination_gloves  \
# number
# 25              not_available           risk_of_shortage
# 47              not_available           risk_of_shortage
#
#        ipc_ppe_surgical_gloves ipc_ppe_long_cuffed_gloves  \
# number
# 25               not_available              not_available
# 47               not_available              not_available
#
#        ipc_ppe_heavy_duty_gloves ipc_ppe_long_sleeved_gown  \
# number
# 25                 not_available             not_available
# 47                 not_available             not_available
#
#        ipc_ppe_waterproof_aprons ipc_ppe_plan_staff_trained_on_ppe  \
# number
# 25                 not_available                     not_available
# 47                 not_available                     not_available
#
#        ipc_ppe_plan_ppe_poster_displayed ipc_ppe_plan_fit_test_kit  \
# number
# 25                         not_available             not_available
# 47                         not_available             not_available
#
#        ipc_ppe_plan_contingency_for_shortages ipc_wcd_colour_coded_bins  \
# number
# 25                         partially_achieved          risk_of_shortage
# 47                         partially_achieved          risk_of_shortage
#
#        ipc_wcd_clinical_waste_bags  \
# number
# 25                risk_of_shortage
# 47                risk_of_shortage
#
#        ipc_wcd_laundry_receptacles_at_patient_rooms ipc_wcd_incinerator  \
# number
# 25                                    not_available       not_available
# 47                                    not_available       not_available
#
#        ipc_wash_clean_running_water ipc_wash_hand_soap ipc_wash_liquid_soap  \
# number
# 25                 risk_of_shortage      not_available        not_available
# 47                 risk_of_shortage      not_available        not_available
#
#        ipc_wash_disp_hand_towels ipc_wash_alcohol_based_hand_gel  \
# number
# 25                 not_available                   not_available
# 47                 not_available                   not_available
#
#        ipc_ds_protocol_facility_disinfection  \
# number
# 25                          risk_of_shortage
# 47                          risk_of_shortage
#
#        ipc_ds_protocol_equipment_sterilisation  \
# number
# 25                               not_available
# 47                               not_available
#
#        ipc_ds_environmental_disinfectant ipc_ds_cleaning_schedule_in_toilets  \
# number
# 25                         not_available                    risk_of_shortage
# 47                         not_available                    risk_of_shortage
#
#        ipc_ds_protocol_corpse_handling log_referral_plan  \
# number
# 25                       not_available         available
# 47                       not_available         available
#
#        log_cellphone_landline_swradio     log_tracer_drugs log_albendazole  \
# number
# 25                      not_available  partially_available       available
# 47                      not_available        not_available       available
#
#             log_amoxicillin       log_ampicillin  log_chlorhexidine_5  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_chlorhexidine_7       log_gentamicin      log_folic  \
# number
# 25           not_available  partially_available  not_available
# 47           not_available  partially_available  not_available
#
#        log_ferrous_and_folic log_compound_sodium log_co_trimoxazole_400  \
# number
# 25             not_available       not_available          not_available
# 47             not_available       not_available          not_available
#
#        log_co_trimoxazole_200 log_metronidazole_250 log_metronidazole_200  \
# number
# 25              not_available   partially_available         not_available
# 47              not_available   partially_available         not_available
#
#              log_methyldopa log_magnesium_sulphate        log_lidocaine  \
# number
# 25      partially_available    partially_available  partially_available
# 47      partially_available    partially_available  partially_available
#
#         log_ibuprofen log_surgical_spirit  log_sodium_chloride   log_povidone  \
# number
# 25      not_available       not_available  partially_available  not_available
# 47      not_available       not_available  partially_available  not_available
#
#        log_paracetamol_500 log_paracetamol_250              log_ors  \
# number
# 25           not_available       not_available  partially_available
# 47           not_available       not_available  partially_available
#
#             log_gauze      log_cotton_wool log_cannula_iv_20  \
# number
# 25      not_available  partially_available     not_available
# 47      not_available  partially_available     not_available
#
#        log_cannula_iv_24    log_zinc_sulphate            log_water  \
# number
# 25         not_available  partially_available  partially_available
# 47         not_available  partially_available  partially_available
#
#               log_needle_23  log_needle_21     log_glove_giving  \
# number
# 25      partially_available  not_available  partially_available
# 47      partially_available  not_available  partially_available
#
#          log_glove_surgical  log_glove_gyn       log_glove_exam  \
# number
# 25      partially_available  not_available  partially_available
# 47            not_available  not_available  partially_available
#
#                    log_tape          log_syringe         log_oxytocin  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_diazepam log_misoprostol    log_glucose  \
# number
# 25        available   not_available  not_available
# 47        available   not_available  not_available
#
#         consultations.head_count.monthly_average_head_counts  \
# number
# 25                                                  226.0
# 47                                                  226.0
#
#         consultations.general_outpatient.monthly_average_general_outpatient  \
# number
# 25                                                  59.75
# 47                                                  59.75
#
#         consultations.deliveries.monthly_average_deliveries  \
# number
# 25                                                   14.0
# 47                                                   14.0
#
#         consultations.pent_vaccines.monthly_average_pent_vaccines  \
# number
# 25                                                   16.5
# 47                                                   16.5
#
#         score_human_resources  score_max_human_resources  \
# number
# 25                        0.5                        5.0
# 47                        0.5                        5.0
#
#         score_information_education_communication  \
# number
# 25                                            1.0
# 47                                            1.0
#
#         score_max_information_education_communication  score_surveillance  \
# number
# 25                                                7.0                 0.5
# 47                                                7.0                 2.0
#
#         score_max_surveillance  score_triage_and_early_recognition  \
# number
# 25                         4.0                                 1.0
# 47                         4.0                                 1.5
#
#         score_max_triage_and_early_recognition  score_chw  score_max_chw  \
# number
# 25                                         5.0        0.5            6.0
# 47                                         5.0        0.0            6.0
#
#         score_isolation  score_max_isolation  \
# number
# 25                  3.0                  4.0
# 47                  3.0                  4.0
#
#         score_infection_prevention_and_control_ppe  \
# number
# 25                                             1.0
# 47                                             1.0
#
#         score_max_infection_prevention_and_control_ppe  \
# number
# 25                                                 9.0
# 47                                                 9.0
#
#         score_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                  0.5
# 47                                                  0.5
#
#         score_max_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    1.0
# 47                                                    1.0
#
#         score_max_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control  \
# number
# 25                                         3.5
# 47                                         3.5
#
#         score_max_infection_prevention_and_control  \
# number
# 25                                            27.0
# 47                                            27.0
#
#         question1.score_logistics_patient_and_sample_transfer  \
# number
# 25                                                   12.0
# 47                                                   11.0
#
#         question1.score_max_logistics_patient_and_sample_transfer  \
# number
# 25                                                   44.0
# 47                                                   44.0
#
#         score_total  score_max_total
# number
# 25             22.0            102.0
# 47             22.5            102.0

# %% [markdown]
# I'm confident that the duplicates in df_dup_2 are genuine duplicates, so I'm going to remove them from df_dup_potential to make it easier to examine the more dubious cases.

# %%
dup_2_indices = list(df_dup_2.index)

# %%
df_dup_potential_2 = df_dup_potential.drop(dup_2_indices,axis=0)

# %%
df_dup_potential_2
# Out:
# Empty DataFrame
# Columns: [facility_name, facility_gps_lat, facility_gps_lon, region_province, district, chiefdom, facility_location, facility_type, facility_type_other, managing_authority, managing_authority_other, setting, outpatient_only, capacity.number_consultation_rooms, capacity.number_inpatient_beds, capacity.number_maternity_beds, cho_number_in_post, cho_number_present_at_visit, cht_number_in_post, cht_number_present_at_visit, cha_number_in_post, cha_number_present_at_visit, cm_number_in_post, cm_number_present_at_visit, sechn_number_in_post, sechn_number_present_at_visit, lab_tech_number_in_post, lab_tech_number_present_at_visit, mch_aides_number_in_post, mch_aides_number_present_at_visit, cleaner_porter_number_in_post, cleaner_porter_number_present_at_visit, other_number_in_post, other_number_present_at_visit, other_staff_cadre, sections_to_review, consultations.head_count.month_1, consultations.head_count.month_2, consultations.head_count.month_3, consultations.head_count.month_4, consultations.general_outpatient.month_1, consultations.general_outpatient.month_2, consultations.general_outpatient.month_3, consultations.general_outpatient.month_4, consultations.deliveries.month_1, consultations.deliveries.month_2, consultations.deliveries.month_3, consultations.deliveries.month_4, consultations.pent_vaccines.month_1, consultations.pent_vaccines.month_2, consultations.pent_vaccines.month_3, consultations.pent_vaccines.month_4, hr_focal_point, hr_staff_received_info, hr_healthcare_provider_training, hr_healthcare_provider_revised_training, hr_daily_staff_list, iec_handwashing_procedure, iec_physical_distancing, iec_covering_nose_mouth, iec_early_symptom_recognition, iec_when_facility_vs_home, iec_rational_ppe_use, iec_helpline_number, surv_procedure_for_notification, surv_official_case_definition, surv_hotline_number, surv_timely_data_reported_to_district, ter_screening_area_set_up, ter_symptom_screening_questionnaires, ter_temperature_measurement_at_triage, ter_physical_distancing_in_waiting, ter_separate_waiting_for_symptomatic, chw_trained_precautions, chw_trained_community_service, chw_drugs, chw_gloves, chw_masks, chw_iec_materials, iso_designated_isolation_for_suspected, iso_distance_between_patients_in_waiting, iso_distance_between_patient_beds, iso_transfer_referral_protocol, ipc_ppe_medical_masks, ipc_ppe_disp_surgical_masks, ipc_ppe_eye_protection, ipc_ppe_examination_gloves, ipc_ppe_surgical_gloves, ipc_ppe_long_cuffed_gloves, ipc_ppe_heavy_duty_gloves, ipc_ppe_long_sleeved_gown, ipc_ppe_waterproof_aprons, ipc_ppe_plan_staff_trained_on_ppe, ipc_ppe_plan_ppe_poster_displayed, ipc_ppe_plan_fit_test_kit, ipc_ppe_plan_contingency_for_shortages, ipc_wcd_colour_coded_bins, ipc_wcd_clinical_waste_bags, ipc_wcd_laundry_receptacles_at_patient_rooms, ipc_wcd_incinerator, ...]
# Index: []

# %% [markdown]
# Now we're left with only four more potential duplicates to investigate.

# %% [markdown]
# For each potential match, let's make a mini dataframe.

# %%
display(df_dup_potential_2['facility_name'].isnull())
# Out:
# Series([], Name: facility_name, dtype: bool)

# %%
mini_dfs = []
mini_df_dict = {}
clinic_names = df_dup_potential_2['facility_name'].unique()
for name in clinic_names:
    if not pd.isnull(name): # if the facility name is not null
        mini_df = df_dup_potential_2[df_dup_potential_2['facility_name']==name]
    else: # when the facility name is null   
        mini_df = df_dup_potential_2[df_dup_potential_2['facility_name'].isnull()]
    mini_df_dict[name]=mini_df
    mini_dfs.append(mini_df)

# %%
for i,mini_df in enumerate(mini_dfs):
    facility_name = mini_df['facility_name'].iloc[0]
    print(f'Facility name: {facility_name}')
    indices = list(mini_df.index)
    print('Where the rows differ: ')
    display(mini_df[mini_df.columns[(mini_df.loc[indices[0]] != mini_df.loc[indices[1]]) & (~(pd.isnull(mini_df.loc[indices[0]]) & pd.isnull(mini_df.loc[indices[1]])))]])
    print('Where the rows are the same: ')
    display(mini_df[mini_df.columns[(mini_df.loc[indices[0]] == mini_df.loc[indices[1]]) | (pd.isnull(mini_df.loc[indices[0]]) & pd.isnull(mini_df.loc[indices[1]]))]])

# %% [markdown]
# * JOHN CLINIC: The two rows are sufficiently different that I'm not sure enough that this is the same clinic to merge the rows into one or delete one of them. I therefore leave them as is.
# * KEVIN HOSPITAL: The two rows match in enough places that they are probably referring to the same clinic. They still differ in many places, however. I will merge them, but record both originals in a separate file and make the merging easy to comment out.
# * RICHARD MCHP: The two rows match in enough places that they are probably referring to the same clinic. They still differ in many places, however. I will merge them, but record both originals in a separate file and make the merging easy to comment out.
# * N/A: The rows are very different, so I leave these as two facilities.

# %% [markdown]
# ### Merging rows

# %% [markdown]
# I will merge the following rows:
# * KEVIN HOSPITAL (indices 133 and 39)
# * RICHARD MCHP (indices 96 and 97)
# * All the facility name pairs in df_dup_2

# %% [markdown]
# Before doing any merging, I will export the duplicates to a csv file so that the machine learning engineer can examine it.

# %%
df_dup = df_dup_2#pd.concat([df_dup_2,mini_df_dict['KEVIN HOSPITAL'],mini_df_dict['RICHARD MCHP']])
print(f'Duplicated indices in df_dup: {sum(df_dup.index.duplicated())}')
df_dup.to_csv('similar_rows.csv')
df_dup
# Out:
# Duplicated indices in df_dup: 0
#         facility_name  facility_gps_lat  facility_gps_lon region_province  \
# number
# 25      JOANNA CLINIC         15.754015       -153.871776        SOUTHERN
# 47      JOANNA CLINIC         60.190934        162.787117        SOUTHERN
#
#        district     chiefdom facility_location facility_type  \
# number
# 25           BO  MISSISSIPPI      AMBERCHESTER      mch_post
# 47           BO  MISSISSIPPI      AMBERCHESTER      mch_post
#
#        facility_type_other managing_authority managing_authority_other  \
# number
# 25                    <NA>  government_public                     <NA>
# 47                    <NA>  government_public                     <NA>
#
#            setting  outpatient_only  capacity.number_consultation_rooms  \
# number
# 25           rural             True                                   1
# 47      peri_urban             True                                   1
#
#         capacity.number_inpatient_beds  capacity.number_maternity_beds  \
# number
# 25                                   2                               1
# 47                                   2                               1
#
#         cho_number_in_post  cho_number_present_at_visit  cht_number_in_post  \
# number
# 25                       0                            0                   0
# 47                       0                            0                   0
#
#         cht_number_present_at_visit  cha_number_in_post  \
# number
# 25                                0                   0
# 47                                0                   0
#
#         cha_number_present_at_visit  cm_number_in_post  \
# number
# 25                                0                  0
# 47                                0                  0
#
#         cm_number_present_at_visit  sechn_number_in_post  \
# number
# 25                               0                     0
# 47                               0                     0
#
#         sechn_number_present_at_visit  lab_tech_number_in_post  \
# number
# 25                                  0                        0
# 47                                  0                        0
#
#         lab_tech_number_present_at_visit  mch_aides_number_in_post  \
# number
# 25                                     0                         3
# 47                                     0                         3
#
#         mch_aides_number_present_at_visit  cleaner_porter_number_in_post  \
# number
# 25                                      2                              1
# 47                                      2                              1
#
#         cleaner_porter_number_present_at_visit  other_number_in_post  \
# number
# 25                                           1                     4
# 47                                           1                     4
#
#         other_number_present_at_visit other_staff_cadre  \
# number
# 25                                  0             TBA's
# 47                                  0             TBA's
#
#                                        sections_to_review  \
# number
# 25      consultations hr information_education_communi...
# 47      consultations hr information_education_communi...
#
#         consultations.head_count.month_1  consultations.head_count.month_2  \
# number
# 25                                   388                               153
# 47                                   388                               153
#
#         consultations.head_count.month_3  consultations.head_count.month_4  \
# number
# 25                                   180                               183
# 47                                   180                               183
#
#         consultations.general_outpatient.month_1  \
# number
# 25                                           133
# 47                                           133
#
#         consultations.general_outpatient.month_2  \
# number
# 25                                            30
# 47                                            30
#
#         consultations.general_outpatient.month_3  \
# number
# 25                                            21
# 47                                            21
#
#         consultations.general_outpatient.month_4  \
# number
# 25                                            55
# 47                                            55
#
#         consultations.deliveries.month_1  consultations.deliveries.month_2  \
# number
# 25                                    18                                10
# 47                                    18                                10
#
#         consultations.deliveries.month_3  consultations.deliveries.month_4  \
# number
# 25                                    14                                14
# 47                                    14                                14
#
#         consultations.pent_vaccines.month_1  \
# number
# 25                                       17
# 47                                       17
#
#         consultations.pent_vaccines.month_2  \
# number
# 25                                       18
# 47                                       18
#
#         consultations.pent_vaccines.month_3  \
# number
# 25                                       12
# 47                                       12
#
#         consultations.pent_vaccines.month_4 hr_focal_point  \
# number
# 25                                       19  not_completed
# 47                                       19  not_completed
#
#        hr_staff_received_info hr_healthcare_provider_training  \
# number
# 25        partially_completed                   not_completed
# 47        partially_completed                   not_completed
#
#        hr_healthcare_provider_revised_training hr_daily_staff_list  \
# number
# 25                               not_completed       not_completed
# 47                               not_completed       not_completed
#
#        iec_handwashing_procedure iec_physical_distancing  \
# number
# 25                 not_displayed           not_displayed
# 47                 not_displayed           not_displayed
#
#        iec_covering_nose_mouth iec_early_symptom_recognition  \
# number
# 25               not_displayed                 not_displayed
# 47               not_displayed                 not_displayed
#
#        iec_when_facility_vs_home iec_rational_ppe_use iec_helpline_number  \
# number
# 25                 not_displayed            displayed       not_displayed
# 47                 not_displayed            displayed       not_displayed
#
#        surv_procedure_for_notification surv_official_case_definition  \
# number
# 25                        not_in_place                  not_in_place
# 47                        not_in_place                  not_in_place
#
#           surv_hotline_number surv_timely_data_reported_to_district  \
# number
# 25      partially_operational                          not_in_place
# 47          fully_operational                     fully_operational
#
#        ter_screening_area_set_up ter_symptom_screening_questionnaires  \
# number
# 25                  not_in_place                         not_in_place
# 47         partially_operational                         not_in_place
#
#        ter_temperature_measurement_at_triage  \
# number
# 25                              not_in_place
# 47                              not_in_place
#
#        ter_physical_distancing_in_waiting  \
# number
# 25                      fully_operational
# 47                      fully_operational
#
#        ter_separate_waiting_for_symptomatic chw_trained_precautions  \
# number
# 25                             not_in_place            not_in_place
# 47                             not_in_place            not_in_place
#
#        chw_trained_community_service     chw_drugs    chw_gloves  \
# number
# 25                      not_in_place       partial  not_in_place
# 47                      not_in_place  not_in_place  not_in_place
#
#            chw_masks chw_iec_materials iso_designated_isolation_for_suspected  \
# number
# 25              <NA>      not_in_place                           not_in_place
# 47      not_in_place      not_in_place                           not_in_place
#
#        iso_distance_between_patients_in_waiting  \
# number
# 25                            fully_operational
# 47                            fully_operational
#
#        iso_distance_between_patient_beds iso_transfer_referral_protocol  \
# number
# 25                     fully_operational              fully_operational
# 47                     fully_operational              fully_operational
#
#        ipc_ppe_medical_masks ipc_ppe_disp_surgical_masks  \
# number
# 25          risk_of_shortage               not_available
# 47          risk_of_shortage               not_available
#
#        ipc_ppe_eye_protection ipc_ppe_examination_gloves  \
# number
# 25              not_available           risk_of_shortage
# 47              not_available           risk_of_shortage
#
#        ipc_ppe_surgical_gloves ipc_ppe_long_cuffed_gloves  \
# number
# 25               not_available              not_available
# 47               not_available              not_available
#
#        ipc_ppe_heavy_duty_gloves ipc_ppe_long_sleeved_gown  \
# number
# 25                 not_available             not_available
# 47                 not_available             not_available
#
#        ipc_ppe_waterproof_aprons ipc_ppe_plan_staff_trained_on_ppe  \
# number
# 25                 not_available                     not_available
# 47                 not_available                     not_available
#
#        ipc_ppe_plan_ppe_poster_displayed ipc_ppe_plan_fit_test_kit  \
# number
# 25                         not_available             not_available
# 47                         not_available             not_available
#
#        ipc_ppe_plan_contingency_for_shortages ipc_wcd_colour_coded_bins  \
# number
# 25                         partially_achieved          risk_of_shortage
# 47                         partially_achieved          risk_of_shortage
#
#        ipc_wcd_clinical_waste_bags  \
# number
# 25                risk_of_shortage
# 47                risk_of_shortage
#
#        ipc_wcd_laundry_receptacles_at_patient_rooms ipc_wcd_incinerator  \
# number
# 25                                    not_available       not_available
# 47                                    not_available       not_available
#
#        ipc_wash_clean_running_water ipc_wash_hand_soap ipc_wash_liquid_soap  \
# number
# 25                 risk_of_shortage      not_available        not_available
# 47                 risk_of_shortage      not_available        not_available
#
#        ipc_wash_disp_hand_towels ipc_wash_alcohol_based_hand_gel  \
# number
# 25                 not_available                   not_available
# 47                 not_available                   not_available
#
#        ipc_ds_protocol_facility_disinfection  \
# number
# 25                          risk_of_shortage
# 47                          risk_of_shortage
#
#        ipc_ds_protocol_equipment_sterilisation  \
# number
# 25                               not_available
# 47                               not_available
#
#        ipc_ds_environmental_disinfectant ipc_ds_cleaning_schedule_in_toilets  \
# number
# 25                         not_available                    risk_of_shortage
# 47                         not_available                    risk_of_shortage
#
#        ipc_ds_protocol_corpse_handling log_referral_plan  \
# number
# 25                       not_available         available
# 47                       not_available         available
#
#        log_cellphone_landline_swradio     log_tracer_drugs log_albendazole  \
# number
# 25                      not_available  partially_available       available
# 47                      not_available        not_available       available
#
#             log_amoxicillin       log_ampicillin  log_chlorhexidine_5  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_chlorhexidine_7       log_gentamicin      log_folic  \
# number
# 25           not_available  partially_available  not_available
# 47           not_available  partially_available  not_available
#
#        log_ferrous_and_folic log_compound_sodium log_co_trimoxazole_400  \
# number
# 25             not_available       not_available          not_available
# 47             not_available       not_available          not_available
#
#        log_co_trimoxazole_200 log_metronidazole_250 log_metronidazole_200  \
# number
# 25              not_available   partially_available         not_available
# 47              not_available   partially_available         not_available
#
#              log_methyldopa log_magnesium_sulphate        log_lidocaine  \
# number
# 25      partially_available    partially_available  partially_available
# 47      partially_available    partially_available  partially_available
#
#         log_ibuprofen log_surgical_spirit  log_sodium_chloride   log_povidone  \
# number
# 25      not_available       not_available  partially_available  not_available
# 47      not_available       not_available  partially_available  not_available
#
#        log_paracetamol_500 log_paracetamol_250              log_ors  \
# number
# 25           not_available       not_available  partially_available
# 47           not_available       not_available  partially_available
#
#             log_gauze      log_cotton_wool log_cannula_iv_20  \
# number
# 25      not_available  partially_available     not_available
# 47      not_available  partially_available     not_available
#
#        log_cannula_iv_24    log_zinc_sulphate            log_water  \
# number
# 25         not_available  partially_available  partially_available
# 47         not_available  partially_available  partially_available
#
#               log_needle_23  log_needle_21     log_glove_giving  \
# number
# 25      partially_available  not_available  partially_available
# 47      partially_available  not_available  partially_available
#
#          log_glove_surgical  log_glove_gyn       log_glove_exam  \
# number
# 25      partially_available  not_available  partially_available
# 47            not_available  not_available  partially_available
#
#                    log_tape          log_syringe         log_oxytocin  \
# number
# 25      partially_available  partially_available  partially_available
# 47      partially_available  partially_available  partially_available
#
#        log_diazepam log_misoprostol    log_glucose  \
# number
# 25        available   not_available  not_available
# 47        available   not_available  not_available
#
#         consultations.head_count.monthly_average_head_counts  \
# number
# 25                                                  226.0
# 47                                                  226.0
#
#         consultations.general_outpatient.monthly_average_general_outpatient  \
# number
# 25                                                  59.75
# 47                                                  59.75
#
#         consultations.deliveries.monthly_average_deliveries  \
# number
# 25                                                   14.0
# 47                                                   14.0
#
#         consultations.pent_vaccines.monthly_average_pent_vaccines  \
# number
# 25                                                   16.5
# 47                                                   16.5
#
#         score_human_resources  score_max_human_resources  \
# number
# 25                        0.5                        5.0
# 47                        0.5                        5.0
#
#         score_information_education_communication  \
# number
# 25                                            1.0
# 47                                            1.0
#
#         score_max_information_education_communication  score_surveillance  \
# number
# 25                                                7.0                 0.5
# 47                                                7.0                 2.0
#
#         score_max_surveillance  score_triage_and_early_recognition  \
# number
# 25                         4.0                                 1.0
# 47                         4.0                                 1.5
#
#         score_max_triage_and_early_recognition  score_chw  score_max_chw  \
# number
# 25                                         5.0        0.5            6.0
# 47                                         5.0        0.0            6.0
#
#         score_isolation  score_max_isolation  \
# number
# 25                  3.0                  4.0
# 47                  3.0                  4.0
#
#         score_infection_prevention_and_control_ppe  \
# number
# 25                                             1.0
# 47                                             1.0
#
#         score_max_infection_prevention_and_control_ppe  \
# number
# 25                                                 9.0
# 47                                                 9.0
#
#         score_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                  0.5
# 47                                                  0.5
#
#         score_max_infection_prevention_and_control_ppe_plan  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    1.0
# 47                                                    1.0
#
#         score_max_infection_prevention_and_control_waste_collection_and_disposal  \
# number
# 25                                                    4.0
# 47                                                    4.0
#
#         score_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_water_sanitation_and_hygiene  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    0.5
# 47                                                    0.5
#
#         score_max_infection_prevention_and_control_disinfection_and_sterilization  \
# number
# 25                                                    5.0
# 47                                                    5.0
#
#         score_infection_prevention_and_control  \
# number
# 25                                         3.5
# 47                                         3.5
#
#         score_max_infection_prevention_and_control  \
# number
# 25                                            27.0
# 47                                            27.0
#
#         question1.score_logistics_patient_and_sample_transfer  \
# number
# 25                                                   12.0
# 47                                                   11.0
#
#         question1.score_max_logistics_patient_and_sample_transfer  \
# number
# 25                                                   44.0
# 47                                                   44.0
#
#         score_total  score_max_total
# number
# 25             22.0            102.0
# 47             22.5            102.0

# %% [markdown]
# Deciding how to merge these rows is tricky. There is no obviously correct way to decide which row of a pair is more valid. I'll therefore write two functions:
#
# (1) A function that takes the first row of each pair when neither value is NaN, and takes the non-NaN value when one is NaN
#
#
# (2) A function that does some more complex merging.

# %%
def merge_super_simple(df_dup):
    
    
    df_dup = df_dup.groupby('facility_name', as_index=False).first()#.agg({'Hobbies' : 'first', 'Name' : ' '.join})
    
    return df_dup
def merge_simple(df_dup):
    
    
    df_dup = df_dup.groupby('facility_name', as_index=False).apply(lambda x: x, axis=1)#.agg({'Hobbies' : 'first', 'Name' : ' '.join})
    display(df_dup)
    """names = df_dup['facility_name'].unique()
    for i,name in enumerate(names):
        # remember to deal with NA name
        mini_df = df_dup[df_dup['facility_name']==name]
        indices = list(mini_df.index)
        display(mini_df)
        
        combo_series = mini_df.loc[indices[0]].combine_first(mini_df.loc[indices[1]])
        
    
    
        df_dup = pd.concat([df_dup, combo_series.to_frame().T])
        display(df_dup)
        #df = df.drop([48,87],axis=0)
        #df[df['facility_name']=='AMY CHP']
    """
    return df_dup

# %%
def merge_complex(df_dup):
    return df_dup

# %%
df_dup_simple = merge_simple(df_dup)
df_dup_simple.to_csv('merged_rows_simple.csv')
df_dup_complex = merge_complex(df_dup)
df_dup_complex.to_csv('merged_rows_complex.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1558, in GroupBy.apply(self, func, *args, **kwargs)
#    1557 try:
# -> 1558     result = self._python_apply_general(f, self._selected_obj)
#    1559 except TypeError:
#    1560     # gh-20949
#    1561     # try again, with .apply acting as a filtering
#    (...)
#    1565     # fails on *some* columns, e.g. a numeric operation
#    1566     # on a string grouper column
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1610, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1582 """
#    1583 Apply function f in python space
#    1584
#    (...)
#    1608     data after applying f
#    1609 """
# -> 1610 values, mutated = self.grouper.apply(f, data, self.axis)
#    1611 if not_indexed_same is None:
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1541, in GroupBy.apply.<locals>.f(g)
#    1540 with np.errstate(all="ignore"):
# -> 1541     return func(g, *args, **kwargs)
#
# TypeError: merge_simple.<locals>.<lambda>() got an unexpected keyword argument 'axis'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [372], line 1
# ----> 1 df_dup_simple = merge_simple(df_dup)
#       2 df_dup_simple.to_csv('merged_rows_simple.csv')
#       3 df_dup_complex = merge_complex(df_dup)
#
# Cell In [370], line 10, in merge_simple(df_dup)
#       7 def merge_simple(df_dup):
# ---> 10     df_dup = df_dup.groupby('facility_name', as_index=False).apply(lambda x: x, axis=1)#.agg({'Hobbies' : 'first', 'Name' : ' '.join})
#      11     display(df_dup)
#      12     """names = df_dup['facility_name'].unique()
#      13     for i,name in enumerate(names):
#      14         # remember to deal with NA name
#    (...)
#      26         #df[df['facility_name']=='AMY CHP']
#      27     """
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1569, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     except TypeError:
#    1560         # gh-20949
#    1561         # try again, with .apply acting as a filtering
#    (...)
#    1565         # fails on *some* columns, e.g. a numeric operation
#    1566         # on a string grouper column
#    1568         with self._group_selection_context():
# -> 1569             return self._python_apply_general(f, self._selected_obj)
#    1571 return result
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1610, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1573 @final
#    1574 def _python_apply_general(
#    1575     self,
#    (...)
#    1580     is_agg: bool = False,
#    1581 ) -> NDFrameT:
#    1582     """
#    1583     Apply function f in python space
#    1584
#    (...)
#    1608         data after applying f
#    1609     """
# -> 1610     values, mutated = self.grouper.apply(f, data, self.axis)
#    1611     if not_indexed_same is None:
#    1612         not_indexed_same = mutated or self.mutated
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File ~/code/macro_eyes/venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1541, in GroupBy.apply.<locals>.f(g)
#    1538 @wraps(func)
#    1539 def f(g):
#    1540     with np.errstate(all="ignore"):
# -> 1541         return func(g, *args, **kwargs)
#
# TypeError: merge_simple.<locals>.<lambda>() got an unexpected keyword argument 'axis'

# %%
def make_final_df(df,df_dup):
    # drop all rows in df whose indices are in dp_dup
    # merge df and df_dup
    return df

# %%
df = make_final_df(df,df_dup_simple) # edit the second parameter to use the duplicates dataframe of your choice

# %% [markdown]
# ## Export final dataframe

# %%
df.to_csv('health_facility_assessment_cleaned.csv', header=True, index=True, index_label=None)
